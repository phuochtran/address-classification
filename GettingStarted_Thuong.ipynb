# %%
# NOTE: you CAN change this cell
# If you want to use your own database, download it here
# !gdown ...
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# NOTE: you CAN change this cell
# Add more to your needs
# you must place ALL pip install here
# !pip install rapidfuzz
# Out:
# Collecting rapidfuzz
#   Downloading rapidfuzz-3.14.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (12 kB)
# Downloading rapidfuzz-3.14.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 34.8 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz
# Successfully installed rapidfuzz-3.14.1

# %%
# NOTE: you CAN change this cell
# import your library here
import time
import re
import json
import unicodedata
from collections import defaultdict
from rapidfuzz import fuzz, process

# %% [markdown]
# # Algorithm

# %%
class Solution:
    def __init__(self):
        base_path = '/content/drive/MyDrive/Test/'
        self.province_path = f'{base_path}/list_province.txt'
        self.district_path = f'{base_path}/list_district.txt'
        self.ward_path = f'{base_path}/list_ward.txt'
        self.master_json_path = f'{base_path}/dvhcvn.json'

        self.threshold = 88

        print("Initializing Solution...")
        start_time = time.time()
        self.provinces = self._load_valid_list(self.province_path)
        self.districts = self._load_valid_list(self.district_path)
        self.wards = self._load_valid_list(self.ward_path)
        self._build_address_map_and_lookup()
        print(f"Solution initialized in {time.time() - start_time:.2f}s.")

    def _clean_name_prefix(self, name: str) -> str:
        if not name: return ""
        prefixes = ["Thành phố", "Tỉnh", "Thị xã", "Huyện", "Quận", "Phường", "Xã", "Thị trấn", "TP"]
        prefixes.sort(key=len, reverse=True)
        name_lower = name.lower()
        for prefix in prefixes:
            if name_lower.startswith(prefix.lower() + ' '): return name[len(prefix):].strip()
        return name.strip()

    def _normalize(self, s: str) -> str:
        if not s: return ""
        s = s.lower()
        s = re.sub(r'd\.', 'd', s)
        s = re.sub(r'\b(tp|thanh pho|tinh)\b', ' Tỉnh ', s)
        s = re.sub(r'\b(q|quan|h|huyen|tx|thi xa)\b', ' Huyện ', s)
        s = re.sub(r'\b(p|phuong|x|xa|tt|thi tran)\b', ' Xã ', s)
        s = unicodedata.normalize('NFD', s)
        s = ''.join(ch for ch in s if unicodedata.category(ch) != 'Mn')
        s = unicodedata.normalize('NFC', s)
        s = re.sub(r'[^a-z0-9\s]', '', s)
        s = re.sub(r'\s+', ' ', s).strip()
        return s

    def _load_valid_list(self, file_path):
        try:
            with open(file_path, 'r', encoding='utf-8') as f:
                lines = [self._clean_name_prefix(line.strip()) for line in f if line.strip()]
                return {self._normalize(line): line for line in lines}
        except FileNotFoundError: return {}

    def _build_address_map_and_lookup(self):
        with open(self.master_json_path, 'r', encoding='utf-8') as f:
            full_data = json.load(f)['data']
        self.address_map = {}
        self.district_to_province = {}
        self.ward_to_district = {}
        for p_data in full_data:
            p_norm = self._normalize(self._clean_name_prefix(p_data['name']))
            if p_norm not in self.address_map: self.address_map[p_norm] = {}
            for d_data in p_data.get('level2s', []):
                d_norm = self._normalize(self._clean_name_prefix(d_data['name']))
                self.district_to_province[d_norm] = p_norm
                if d_norm not in self.address_map[p_norm]: self.address_map[p_norm][d_norm] = set()
                for w_data in d_data.get('level3s', []):
                    w_norm = self._normalize(self._clean_name_prefix(w_data['name']))
                    self.address_map[p_norm][d_norm].add(w_norm)
                    if w_norm not in self.ward_to_district: self.ward_to_district[w_norm] = w_norm

    def _urban_handler(self, normalized_ocr, p_cand):
        d_match = re.search(r'huyen\s+(\d+)', normalized_ocr)
        w_match = re.search(r'xa\s+(\d+)', normalized_ocr)
        d_num = d_match.group(1) if d_match else None
        w_num = w_match.group(1) if w_match else None

        if p_cand and d_num and d_num in self.address_map.get(p_cand, {}):
            w_result = w_num if w_num and w_num in self.address_map.get(p_cand, {}).get(d_num, set()) else None
            return {'p': p_cand, 'd': d_num, 'w': w_result, 'score': 300}
        return None

    def process(self, s: str):
        if not s.strip(): return {"province": "", "district": "", "ward": ""}
        normalized_ocr = self._normalize(s)
        if not normalized_ocr: return {"province": "", "district": "", "ward": ""}

        hypotheses = []
        p_candidates = process.extract(normalized_ocr, self.provinces.keys(), scorer=fuzz.WRatio, limit=3, score_cutoff=self.threshold - 5)

        # Tinh > Huyen > Xa
        for p_cand, p_score, _ in p_candidates:
            urban_res = self._urban_handler(normalized_ocr, p_cand)
            if urban_res: hypotheses.append(urban_res)

            hypotheses.append({'p': p_cand, 'd': None, 'w': None, 'score': p_score})

            ocr_after_p = normalized_ocr.replace(p_cand, ' ', 1)
            valid_districts = list(self.address_map.get(p_cand, {}).keys())
            if not valid_districts: continue

            d_candidates = process.extract(ocr_after_p, valid_districts, scorer=fuzz.WRatio, limit=2, score_cutoff=self.threshold)
            for d_cand, d_score, _ in d_candidates:
                hypotheses.append({'p': p_cand, 'd': d_cand, 'w': None, 'score': p_score + d_score})

                ocr_after_d = ocr_after_p.replace(d_cand, ' ', 1)
                valid_wards = list(self.address_map.get(p_cand, {}).get(d_cand, set()))
                if not valid_wards: continue

                w_match = process.extractOne(ocr_after_d, valid_wards, scorer=fuzz.partial_ratio, score_cutoff=90)
                if w_match:
                    w_cand, w_score = w_match[0], w_match[1]
                    hypotheses.append({'p': p_cand, 'd': d_cand, 'w': w_cand, 'score': (p_score + d_score + w_score) * 1.2})

        # Huyen > Xa
        if not hypotheses or max(h.get('score', 0) for h in hypotheses) < 180:
            d_candidates = process.extract(normalized_ocr, self.districts.keys(), scorer=fuzz.WRatio, limit=2, score_cutoff=self.threshold)
            for d_cand, d_score, _ in d_candidates:
                p_inferred = self.district_to_province.get(d_cand)
                p_score_inferred = fuzz.partial_ratio(normalized_ocr, p_inferred)
                if p_score_inferred > 70:
                    hypotheses.append({'p': p_inferred, 'd': d_cand, 'w': None, 'score': d_score + p_score_inferred})

        if not hypotheses: return {"province": "", "district": "", "ward": ""}

        # Chon kq
        best_hypo = max(hypotheses, key=lambda x: x.get('score', 0))

        return {
            "province": self.provinces.get(best_hypo.get('p'), ""),
            "district": self.districts.get(best_hypo.get('d'), ""),
            "ward": self.wards.get(best_hypo.get('w'), "")
        }

# %% [markdown]
# # Run

# %%
# CORRECT TESTS
groups_province = {}
groups_district = {'hòa bình': ['Hoà Bình', 'Hòa Bình'], 'kbang': ['Kbang', 'KBang'], 'quy nhơn': ['Qui Nhơn', 'Quy Nhơn']}
groups_ward = {'ái nghĩa': ['ái Nghĩa', 'Ái Nghĩa'], 'ái quốc': ['ái Quốc', 'Ái Quốc'], 'ái thượng': ['ái Thượng', 'Ái Thượng'], 'ái tử': ['ái Tử', 'Ái Tử'], 'ấm hạ': ['ấm Hạ', 'Ấm Hạ'], 'an ấp': ['An ấp', 'An Ấp'], 'ẳng cang': ['ẳng Cang', 'Ẳng Cang'], 'ẳng nưa': ['ẳng Nưa', 'Ẳng Nưa'], 'ẳng tở': ['ẳng Tở', 'Ẳng Tở'], 'an hòa': ['An Hoà', 'An Hòa'], 'ayun': ['Ayun', 'AYun'], 'bắc ái': ['Bắc ái', 'Bắc Ái'], 'bảo ái': ['Bảo ái', 'Bảo Ái'], 'bình hòa': ['Bình Hoà', 'Bình Hòa'], 'châu ổ': ['Châu ổ', 'Châu Ổ'], 'chư á': ['Chư á', 'Chư Á'], 'chư rcăm': ['Chư Rcăm', 'Chư RCăm'], 'cộng hòa': ['Cộng Hoà', 'Cộng Hòa'], 'cò nòi': ['Cò  Nòi', 'Cò Nòi'], 'đại ân 2': ['Đại Ân  2', 'Đại Ân 2'], 'đak ơ': ['Đak ơ', 'Đak Ơ'], "đạ m'ri": ["Đạ M'ri", "Đạ M'Ri"], 'đông hòa': ['Đông Hoà', 'Đông Hòa'], 'đồng ích': ['Đồng ích', 'Đồng Ích'], 'hải châu i': ['Hải Châu  I', 'Hải Châu I'], 'hải hòa': ['Hải Hoà', 'Hải Hòa'], 'hành tín đông': ['Hành Tín  Đông', 'Hành Tín Đông'], 'hiệp hòa': ['Hiệp Hoà', 'Hiệp Hòa'], 'hòa bắc': ['Hoà Bắc', 'Hòa Bắc'], 'hòa bình': ['Hoà Bình', 'Hòa Bình'], 'hòa châu': ['Hoà Châu', 'Hòa Châu'], 'hòa hải': ['Hoà Hải', 'Hòa Hải'], 'hòa hiệp trung': ['Hoà Hiệp Trung', 'Hòa Hiệp Trung'], 'hòa liên': ['Hoà Liên', 'Hòa Liên'], 'hòa lộc': ['Hoà Lộc', 'Hòa Lộc'], 'hòa lợi': ['Hoà Lợi', 'Hòa Lợi'], 'hòa long': ['Hoà Long', 'Hòa Long'], 'hòa mạc': ['Hoà Mạc', 'Hòa Mạc'], 'hòa minh': ['Hoà Minh', 'Hòa Minh'], 'hòa mỹ': ['Hoà Mỹ', 'Hòa Mỹ'], 'hòa phát': ['Hoà Phát', 'Hòa Phát'], 'hòa phong': ['Hoà Phong', 'Hòa Phong'], 'hòa phú': ['Hoà Phú', 'Hòa Phú'], 'hòa phước': ['Hoà Phước', 'Hòa Phước'], 'hòa sơn': ['Hoà Sơn', 'Hòa Sơn'], 'hòa tân': ['Hoà Tân', 'Hòa Tân'], 'hòa thuận': ['Hoà Thuận', 'Hòa Thuận'], 'hòa tiến': ['Hoà Tiến', 'Hòa Tiến'], 'hòa trạch': ['Hoà Trạch', 'Hòa Trạch'], 'hòa vinh': ['Hoà Vinh', 'Hòa Vinh'], 'hương hòa': ['Hương Hoà', 'Hương Hòa'], 'ích hậu': ['ích Hậu', 'Ích Hậu'], 'ít ong': ['ít Ong', 'Ít Ong'], 'khánh hòa': ['Khánh Hoà', 'Khánh Hòa'], 'krông á': ['Krông Á', 'KRông á'], 'lộc hòa': ['Lộc Hoà', 'Lộc Hòa'], 'minh hòa': ['Minh Hoà', 'Minh Hòa'], 'mường ải': ['Mường ải', 'Mường Ải'], 'mường ẳng': ['Mường ẳng', 'Mường Ẳng'], 'nậm ét': ['Nậm ét', 'Nậm Ét'], 'nam hòa': ['Nam Hoà', 'Nam Hòa'], 'na ư': ['Na ư', 'Na Ư'], 'ngã sáu': ['Ngã sáu', 'Ngã Sáu'], 'nghi hòa': ['Nghi Hoà', 'Nghi Hòa'], 'nguyễn úy': ['Nguyễn Uý', 'Nguyễn úy', 'Nguyễn Úy'], 'nhân hòa': ['Nhân Hoà', 'Nhân Hòa'], 'nhơn hòa': ['Nhơn Hoà', 'Nhơn Hòa'], 'nhơn nghĩa a': ['Nhơn nghĩa A', 'Nhơn Nghĩa A'], 'phúc ứng': ['Phúc ứng', 'Phúc Ứng'], 'phước hòa': ['Phước Hoà', 'Phước Hòa'], 'sơn hóa': ['Sơn Hoá', 'Sơn Hóa'], 'tạ an khương đông': ['Tạ An Khương  Đông', 'Tạ An Khương Đông'], 'tạ an khương nam': ['Tạ An Khương  Nam', 'Tạ An Khương Nam'], 'tăng hòa': ['Tăng Hoà', 'Tăng Hòa'], 'tân hòa': ['Tân Hoà', 'Tân Hòa'], 'tân hòa thành': ['Tân Hòa  Thành', 'Tân Hòa Thành'], 'tân khánh trung': ['Tân  Khánh Trung', 'Tân Khánh Trung'], 'tân lợi': ['Tân lợi', 'Tân Lợi'], 'thái hòa': ['Thái Hoà', 'Thái Hòa'], 'thiết ống': ['Thiết ống', 'Thiết Ống'], 'thuận hòa': ['Thuận Hoà', 'Thuận Hòa'], 'thượng ấm': ['Thượng ấm', 'Thượng Ấm'], 'thụy hương': ['Thuỵ Hương', 'Thụy Hương'], 'thủy xuân': ['Thuỷ Xuân', 'Thủy Xuân'], 'tịnh ấn đông': ['Tịnh ấn Đông', 'Tịnh Ấn Đông'], 'tịnh ấn tây': ['Tịnh ấn Tây', 'Tịnh Ấn Tây'], 'triệu ái': ['Triệu ái', 'Triệu Ái'], 'triệu ẩu': ['Triệu ẩu', 'Triệu Ẩu'], 'trung hòa': ['Trung Hoà', 'Trung Hòa'], 'trung ý': ['Trung ý', 'Trung Ý'], 'tùng ảnh': ['Tùng ảnh', 'Tùng Ảnh'], 'úc kỳ': ['úc Kỳ', 'Úc Kỳ'], 'ứng hòe': ['ứng Hoè', 'Ứng Hoè'], 'vĩnh hòa': ['Vĩnh Hoà', 'Vĩnh Hòa'], 'vũ hòa': ['Vũ Hoà', 'Vũ Hòa'], 'xuân ái': ['Xuân ái', 'Xuân Ái'], 'xuân áng': ['Xuân áng', 'Xuân Áng'], 'xuân hòa': ['Xuân Hoà', 'Xuân Hòa'], 'xuất hóa': ['Xuất Hoá', 'Xuất Hóa'], 'ỷ la': ['ỷ La', 'Ỷ La']}
groups_ward.update({1: ['1', '01'], 2: ['2', '02'], 3: ['3', '03'], 4: ['4', '04'], 5: ['5', '05'], 6: ['6', '06'], 7: ['7', '07'], 8: ['8', '08'], 9: ['9', '09']})
def to_same(groups):
    same = {ele: k for k, v in groups.items() for ele in v}
    return same
same_province = to_same(groups_province)
same_district = to_same(groups_district)
same_ward = to_same(groups_ward)
def normalize(text, same_dict):
    return same_dict.get(text, text)

# %%
TEAM_NAME = 'HK251'
EXCEL_FILE = f'{TEAM_NAME}.xlsx'

import json
import time
with open('/content/drive/MyDrive/Test/test.json') as f:
    data = json.load(f)

summary_only = False

df = []
solution = Solution()
timer = []
correct = 0
for test_idx, data_point in enumerate(data):
    address = data_point["text"]

    ok = 0
    try:
        answer = data_point["result"]
        answer["province_normalized"] = normalize(answer["province"], same_province)
        answer["district_normalized"] = normalize(answer["district"], same_district)
        answer["ward_normalized"] = normalize(answer["ward"], same_ward)

        start = time.perf_counter_ns()
        result = solution.process(address)
        finish = time.perf_counter_ns()
        timer.append(finish - start)
        result["province_normalized"] = normalize(result["province"], same_province)
        result["district_normalized"] = normalize(result["district"], same_district)
        result["ward_normalized"] = normalize(result["ward"], same_ward)

        province_correct = int(answer["province_normalized"] == result["province_normalized"])
        district_correct = int(answer["district_normalized"] == result["district_normalized"])
        ward_correct = int(answer["ward_normalized"] == result["ward_normalized"])
        ok = province_correct + district_correct + ward_correct

        if not summary_only and ok !=3:
            print(f"--- Trường hợp #{test_idx+1} ---")
            print(f"Input    : '{address}'")
            print(f"Expected : {answer}")
            print(f"Actual   : {result}")
            print(f"Correct  : {ok}/3")
            print(f"Time     : {timer[-1] / 1_000_000_000:.6f}s")
            print("-" * 30)
        # ----------------------------------------------------

        df.append([
            test_idx,
            address,
            answer["province"],
            result["province"],
            answer["province_normalized"],
            result["province_normalized"],
            province_correct,
            answer["district"],
            result["district"],
            answer["district_normalized"],
            result["district_normalized"],
            district_correct,
            answer["ward"],
            result["ward"],
            answer["ward_normalized"],
            result["ward_normalized"],
            ward_correct,
            ok,
            timer[-1] / 1_000_000_000,
        ])
    except Exception as e:
        print(f"Lỗi tại trường hợp #{test_idx+1} với input: '{address}'")
        print(f"Exception: {e}")
        df.append([
            test_idx,
            address,
            answer.get("province", "N/A"), "EXCEPTION", answer.get("province_normalized", "N/A"), "EXCEPTION", 0,
            answer.get("district", "N/A"), "EXCEPTION", answer.get("district_normalized", "N/A"), "EXCEPTION", 0,
            answer.get("ward", "N/A"), "EXCEPTION", answer.get("ward_normalized", "N/A"), "EXCEPTION", 0,
            0, 0,
        ])
        pass
    correct += ok


print(f"--- TỔNG KẾT ---")
total = len(data) * 3
score_scale_10 = round(correct / total * 10, 2)
if len(timer) == 0:
    timer = [0]
max_time_sec = round(max(timer) / 1_000_000_000, 4)
avg_time_sec = round((sum(timer) / len(timer)) / 1_000_000_000, 4)

import pandas as pd

df2 = pd.DataFrame(
    [[correct, total, score_scale_10, max_time_sec, avg_time_sec]],
    columns=['correct', 'total', 'score / 10', 'max_time_sec', 'avg_time_sec',],
)


columns = [
    'ID', 'text',
    'province', 'province_student', 'province_normalized', 'province_student_normalized', 'province_correct',
    'district', 'district_student', 'district_normalized', 'district_student_normalized', 'district_correct',
    'ward', 'ward_student', 'ward_normalized', 'ward_student_normalized', 'ward_correct',
    'total_correct', 'time_sec',
]

df = pd.DataFrame(df)
df.columns = columns

print(f'{TEAM_NAME = }')
print(f'{EXCEL_FILE = }')
print(df2)

# !pip install -q xlsxwriter
writer = pd.ExcelWriter(EXCEL_FILE, engine='xlsxwriter')
df2.to_excel(writer, index=False, sheet_name='summary')
df.to_excel(writer, index=False, sheet_name='details')
writer.close()

print(f"\nĐã xuất kết quả chi tiết ra file {EXCEL_FILE}")
# Out:
# Initializing Solution...
# Solution initialized in 1.74s.
# --- Trường hợp #1 ---
# Input    : 'TT Tân Bình Huyện Yên Sơn, Tuyên Quang'
# Expected : {'province': 'Tuyên Quang', 'district': 'Yên Sơn', 'ward': 'Tân Bình', 'province_normalized': 'Tuyên Quang', 'district_normalized': 'Yên Sơn', 'ward_normalized': 'Tân Bình'}
# Actual   : {'province': 'Tuyên Quang', 'district': 'Yên Sơn', 'ward': '', 'province_normalized': 'Tuyên Quang', 'district_normalized': 'Yên Sơn', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.000796s
# ------------------------------
# --- Trường hợp #2 ---
# Input    : '357/28,Ng-T- Thuật,P1,Q3,TP.HồChíMinh.'
# Expected : {'province': 'Hồ Chí Minh', 'district': '', 'ward': '', 'province_normalized': 'Hồ Chí Minh', 'district_normalized': '', 'ward_normalized': ''}
# Actual   : {'province': 'Bình Định', 'district': '', 'ward': '', 'province_normalized': 'Bình Định', 'district_normalized': '', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.000942s
# ------------------------------
# --- Trường hợp #3 ---
# Input    : '284DBis Ng Văn Giáo, P3, Mỹ Tho, T.Giang.'
# Expected : {'province': 'Tiền Giang', 'district': 'Mỹ Tho', 'ward': '3', 'province_normalized': 'Tiền Giang', 'district_normalized': 'Mỹ Tho', 'ward_normalized': 3}
# Actual   : {'province': 'Tiền Giang', 'district': 'Mỹ Tho', 'ward': '', 'province_normalized': 'Tiền Giang', 'district_normalized': 'Mỹ Tho', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.000944s
# ------------------------------
# --- Trường hợp #5 ---
# Input    : '59/12 Ng-B-Khiêm, Đa Kao Quận 1, TP. Hồ Chí Minh'
# Expected : {'province': 'Hồ Chí Minh', 'district': '1', 'ward': 'Đa Kao', 'province_normalized': 'Hồ Chí Minh', 'district_normalized': '1', 'ward_normalized': 'Đa Kao'}
# Actual   : {'province': 'Hồ Chí Minh', 'district': '', 'ward': '', 'province_normalized': 'Hồ Chí Minh', 'district_normalized': '', 'ward_normalized': ''}
# Correct  : 1/3
# Time     : 0.001085s
# ------------------------------
# --- Trường hợp #8 ---
# Input    : 'Thanh Long, Yên Mỹ Hưng Yên'
# Expected : {'province': 'Hưng Yên', 'district': 'Yên Mỹ', 'ward': 'Thanh Long', 'province_normalized': 'Hưng Yên', 'district_normalized': 'Yên Mỹ', 'ward_normalized': 'Thanh Long'}
# Actual   : {'province': 'Hưng Yên', 'district': 'Yên Mỹ', 'ward': 'Thành Long', 'province_normalized': 'Hưng Yên', 'district_normalized': 'Yên Mỹ', 'ward_normalized': 'Thành Long'}
# Correct  : 2/3
# Time     : 0.000383s
# ------------------------------
# --- Trường hợp #10 ---
# Input    : 'Cổ Lũy Hải Ba, Hải Lăng, Quảng Trị'
# Expected : {'province': 'Quảng Trị', 'district': 'Hải Lăng', 'ward': 'Hải Ba', 'province_normalized': 'Quảng Trị', 'district_normalized': 'Hải Lăng', 'ward_normalized': 'Hải Ba'}
# Actual   : {'province': 'Quảng Trị', 'district': 'Hải Lăng', 'ward': '', 'province_normalized': 'Quảng Trị', 'district_normalized': 'Hải Lăng', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.000415s
# ------------------------------
# --- Trường hợp #14 ---
# Input    : 'CH F1614-HH2-Khu ĐTM Dương Nội, Yên Nghĩa, Hà Đông, Hà Nội'
# Expected : {'province': 'Hà Nội', 'district': 'Hà Đông', 'ward': 'Yên Nghĩa', 'province_normalized': 'Hà Nội', 'district_normalized': 'Hà Đông', 'ward_normalized': 'Yên Nghĩa'}
# Actual   : {'province': 'Bình Dương', 'district': '', 'ward': '', 'province_normalized': 'Bình Dương', 'district_normalized': '', 'ward_normalized': ''}
# Correct  : 0/3
# Time     : 0.001068s
# ------------------------------
# --- Trường hợp #24 ---
# Input    : 'Xã Bồng Khê Huyện Con Cuông, Nghệ An'
# Expected : {'province': 'Nghệ An', 'district': 'Con Cuông', 'ward': 'Bồng Khê', 'province_normalized': 'Nghệ An', 'district_normalized': 'Con Cuông', 'ward_normalized': 'Bồng Khê'}
# Actual   : {'province': 'Nghệ An', 'district': 'Con Cuông', 'ward': '', 'province_normalized': 'Nghệ An', 'district_normalized': 'Con Cuông', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.000360s
# ------------------------------
# --- Trường hợp #26 ---
# Input    : 'Số 259/54/8, Tổ 28, KP1, Long Bình Tân, Biên Hòa, Đồng Nai.'
# Expected : {'province': 'Đồng Nai', 'district': 'Biên Hòa', 'ward': 'Long Bình Tân', 'province_normalized': 'Đồng Nai', 'district_normalized': 'Biên Hòa', 'ward_normalized': 'Long Bình Tân'}
# Actual   : {'province': 'Đồng Nai', 'district': 'Biên Hòa', 'ward': 'Long Bình', 'province_normalized': 'Đồng Nai', 'district_normalized': 'Biên Hòa', 'ward_normalized': 'Long Bình'}
# Correct  : 2/3
# Time     : 0.000365s
# ------------------------------
# --- Trường hợp #29 ---
# Input    : 'Tiểu khu 3, thị trấn Ba Hàng, huyện Phổ Yên, tỉnh Thái Nguyên.'
# Expected : {'province': '', 'district': '', 'ward': '', 'province_normalized': '', 'district_normalized': '', 'ward_normalized': ''}
# Actual   : {'province': 'Thái Nguyên', 'district': 'Phổ Yên', 'ward': 'Ba Hàng', 'province_normalized': 'Thái Nguyên', 'district_normalized': 'Phổ Yên', 'ward_normalized': 'Ba Hàng'}
# Correct  : 0/3
# Time     : 0.000320s
# ------------------------------
# --- Trường hợp #30 ---
# Input    : 'Xóm 2, Hưng Mỹ, Hưng Nguyên, Nghệ An'
# Expected : {'province': 'Nghệ An', 'district': 'Hưng Nguyên', 'ward': 'Hưng Mỹ', 'province_normalized': 'Nghệ An', 'district_normalized': 'Hưng Nguyên', 'ward_normalized': 'Hưng Mỹ'}
# Actual   : {'province': 'Nghệ An', 'district': 'Hưng Nguyên', 'ward': '', 'province_normalized': 'Nghệ An', 'district_normalized': 'Hưng Nguyên', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.000434s
# ------------------------------
# --- Trường hợp #32 ---
# Input    : 'Nậm Cha Sìn Hổ, Lai Châu'
# Expected : {'province': 'Lai Châu', 'district': 'Sìn Hồ', 'ward': 'Nậm Cha', 'province_normalized': 'Lai Châu', 'district_normalized': 'Sìn Hồ', 'ward_normalized': 'Nậm Cha'}
# Actual   : {'province': 'Lai Châu', 'district': 'Sìn Hồ', 'ward': 'Nậm Chà', 'province_normalized': 'Lai Châu', 'district_normalized': 'Sìn Hồ', 'ward_normalized': 'Nậm Chà'}
# Correct  : 2/3
# Time     : 0.000311s
# ------------------------------
# --- Trường hợp #34 ---
# Input    : 'P. Nghi Hương Thị xã Cửa Lò, Nghệ An'
# Expected : {'province': 'Nghệ An', 'district': 'Cửa Lò', 'ward': 'Nghi Hương', 'province_normalized': 'Nghệ An', 'district_normalized': 'Cửa Lò', 'ward_normalized': 'Nghi Hương'}
# Actual   : {'province': 'Nghệ An', 'district': '', 'ward': '', 'province_normalized': 'Nghệ An', 'district_normalized': '', 'ward_normalized': ''}
# Correct  : 1/3
# Time     : 0.001068s
# ------------------------------
# --- Trường hợp #35 ---
# Input    : 'Hoằng Anh Thành phố Thanh Hóa, Thanh Hóa'
# Expected : {'province': 'Thanh Hóa', 'district': 'Thanh Hóa', 'ward': 'Hoằng Anh', 'province_normalized': 'Thanh Hóa', 'district_normalized': 'Thanh Hóa', 'ward_normalized': 'Hoằng Anh'}
# Actual   : {'province': 'Thanh Hóa', 'district': 'Thạnh Hóa', 'ward': 'Hoằng Đại', 'province_normalized': 'Thanh Hóa', 'district_normalized': 'Thạnh Hóa', 'ward_normalized': 'Hoằng Đại'}
# Correct  : 1/3
# Time     : 0.000547s
# ------------------------------
# --- Trường hợp #37 ---
# Input    : 'Phường Yên Thanh, thành phố Uông Bí, tỉnh Quảng Ninh.'
# Expected : {'province': 'Quảng Ninh', 'district': 'Uông Bí', 'ward': 'Yên Thanh', 'province_normalized': 'Quảng Ninh', 'district_normalized': 'Uông Bí', 'ward_normalized': 'Yên Thanh'}
# Actual   : {'province': 'Quảng Ninh', 'district': 'Uông Bí', 'ward': 'Yên Thành', 'province_normalized': 'Quảng Ninh', 'district_normalized': 'Uông Bí', 'ward_normalized': 'Yên Thành'}
# Correct  : 2/3
# Time     : 0.000429s
# ------------------------------
# --- Trường hợp #39 ---
# Input    : 'KP 1B, P.An Phú, TX.Thuận An, Bình Dương'
# Expected : {'province': 'Bình Dương', 'district': 'Thuận An', 'ward': 'An Phú', 'province_normalized': 'Bình Dương', 'district_normalized': 'Thuận An', 'ward_normalized': 'An Phú'}
# Actual   : {'province': 'Bình Dương', 'district': 'Thuận An', 'ward': 'Ân Phú', 'province_normalized': 'Bình Dương', 'district_normalized': 'Thuận An', 'ward_normalized': 'Ân Phú'}
# Correct  : 2/3
# Time     : 0.000426s
# ------------------------------
# --- Trường hợp #40 ---
# Input    : 'Thôn Xuân Lũng Bình Trung, Cao Lộc, Lạng Sơn'
# Expected : {'province': 'Lạng Sơn', 'district': 'Cao Lộc', 'ward': 'Bình Trung', 'province_normalized': 'Lạng Sơn', 'district_normalized': 'Cao Lộc', 'ward_normalized': 'Bình Trung'}
# Actual   : {'province': 'Lạng Sơn', 'district': 'Cao Lộc', 'ward': 'Bình Trưng', 'province_normalized': 'Lạng Sơn', 'district_normalized': 'Cao Lộc', 'ward_normalized': 'Bình Trưng'}
# Correct  : 2/3
# Time     : 0.000393s
# ------------------------------
# --- Trường hợp #41 ---
# Input    : 'Phường Hòa Cường Nam, Quận Hải Châu, Thành phố Đà Nẵng.'
# Expected : {'province': 'Đà Nẵng', 'district': 'Hải Châu', 'ward': 'Hòa Cường Nam', 'province_normalized': 'Đà Nẵng', 'district_normalized': 'Hải Châu', 'ward_normalized': 'Hòa Cường Nam'}
# Actual   : {'province': 'Hoà Bình', 'district': '', 'ward': '', 'province_normalized': 'Hoà Bình', 'district_normalized': '', 'ward_normalized': ''}
# Correct  : 0/3
# Time     : 0.001126s
# ------------------------------
# --- Trường hợp #42 ---
# Input    : 'TT. Phù Mỹ Phù Mỹ, Bình Định'
# Expected : {'province': 'Bình Định', 'district': 'Phù Mỹ', 'ward': 'Phù Mỹ', 'province_normalized': 'Bình Định', 'district_normalized': 'Phù Mỹ', 'ward_normalized': 'Phù Mỹ'}
# Actual   : {'province': 'Bình Định', 'district': 'Phú Mỹ', 'ward': 'Phú Mỹ', 'province_normalized': 'Bình Định', 'district_normalized': 'Phú Mỹ', 'ward_normalized': 'Phú Mỹ'}
# Correct  : 1/3
# Time     : 0.000505s
# ------------------------------
# --- Trường hợp #44 ---
# Input    : '154/4/81 Nguyễn - Phúc Chu, P15, TB, TP. Hồ Chí Minh'
# Expected : {'province': '', 'district': '', 'ward': '', 'province_normalized': '', 'district_normalized': '', 'ward_normalized': ''}
# Actual   : {'province': 'Hồ Chí Minh', 'district': '', 'ward': '', 'province_normalized': 'Hồ Chí Minh', 'district_normalized': '', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.001775s
# ------------------------------
# --- Trường hợp #45 ---
# Input    : 'Xã Cao Dương, Huyện Thanh Oai, Thành phố Hà Nội'
# Expected : {'province': 'Hà Nội', 'district': 'Thanh Oai', 'ward': 'Cao Dương', 'province_normalized': 'Hà Nội', 'district_normalized': 'Thanh Oai', 'ward_normalized': 'Cao Dương'}
# Actual   : {'province': 'Hà Nội', 'district': 'Thanh Oai', 'ward': '', 'province_normalized': 'Hà Nội', 'district_normalized': 'Thanh Oai', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.000604s
# ------------------------------
# --- Trường hợp #46 ---
# Input    : 'Tổ 8, Ấp An Bình Minh Hòa, Châu Thành, Kiên Giang'
# Expected : {'province': 'Kiên Giang', 'district': 'Châu Thành', 'ward': 'Minh Hòa', 'province_normalized': 'Kiên Giang', 'district_normalized': 'Châu Thành', 'ward_normalized': 'minh hòa'}
# Actual   : {'province': 'Kiên Giang', 'district': 'Châu Thành', 'ward': 'Minh Hóa', 'province_normalized': 'Kiên Giang', 'district_normalized': 'Châu Thành', 'ward_normalized': 'Minh Hóa'}
# Correct  : 2/3
# Time     : 0.000397s
# ------------------------------
# --- Trường hợp #47 ---
# Input    : 'Khu vực 1 TT Đức Hòa, Đức Hòa, Long An'
# Expected : {'province': 'Long An', 'district': 'Đức Hòa', 'ward': 'Đức Hòa', 'province_normalized': 'Long An', 'district_normalized': 'Đức Hòa', 'ward_normalized': 'Đức Hòa'}
# Actual   : {'province': 'Long An', 'district': 'Đức Hòa', 'ward': 'Đức Hóa', 'province_normalized': 'Long An', 'district_normalized': 'Đức Hòa', 'ward_normalized': 'Đức Hóa'}
# Correct  : 2/3
# Time     : 0.000460s
# ------------------------------
# --- Trường hợp #54 ---
# Input    : 'Thái Hòa Huyện Thái Thụy, Thái Bình'
# Expected : {'province': 'Thái Bình', 'district': 'Thái Thụy', 'ward': 'Thái Hòa', 'province_normalized': 'Thái Bình', 'district_normalized': 'Thái Thụy', 'ward_normalized': 'thái hòa'}
# Actual   : {'province': 'Thái Bình', 'district': 'Thái Thụy', 'ward': 'Thái Thọ', 'province_normalized': 'Thái Bình', 'district_normalized': 'Thái Thụy', 'ward_normalized': 'Thái Thọ'}
# Correct  : 2/3
# Time     : 0.000435s
# ------------------------------
# --- Trường hợp #55 ---
# Input    : 'Xã Thanh Hòa, Huyện Cai Lậy, Tỉnh Tiền Giang'
# Expected : {'province': 'Tiền Giang', 'district': 'Cai Lậy', 'ward': 'Thanh Hòa', 'province_normalized': 'Tiền Giang', 'district_normalized': 'Cai Lậy', 'ward_normalized': 'Thanh Hòa'}
# Actual   : {'province': 'Tiền Giang', 'district': 'Cai Lậy', 'ward': 'Thạnh Hóa', 'province_normalized': 'Tiền Giang', 'district_normalized': 'Cai Lậy', 'ward_normalized': 'Thạnh Hóa'}
# Correct  : 2/3
# Time     : 0.000396s
# ------------------------------
# --- Trường hợp #56 ---
# Input    : 'Thôn 3 Sơn Hải, Quỳnh Lưu, Nghệ An'
# Expected : {'province': 'Nghệ An', 'district': 'Quỳnh Lưu', 'ward': 'Sơn Hải', 'province_normalized': 'Nghệ An', 'district_normalized': 'Quỳnh Lưu', 'ward_normalized': 'Sơn Hải'}
# Actual   : {'province': 'Nghệ An', 'district': 'Quỳnh Lưu', 'ward': '', 'province_normalized': 'Nghệ An', 'district_normalized': 'Quỳnh Lưu', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.000357s
# ------------------------------
# --- Trường hợp #57 ---
# Input    : 'Thôn Thành Bắc, Xã Quảng Thành, TP Thanh Hoá, Thanh Hoá'
# Expected : {'province': 'Thanh Hóa', 'district': 'Thanh Hóa', 'ward': 'Quảng Thành', 'province_normalized': 'Thanh Hóa', 'district_normalized': 'Thanh Hóa', 'ward_normalized': 'Quảng Thành'}
# Actual   : {'province': 'Thanh Hóa', 'district': 'Thạnh Hóa', 'ward': 'Quảng Thành', 'province_normalized': 'Thanh Hóa', 'district_normalized': 'Thạnh Hóa', 'ward_normalized': 'Quảng Thành'}
# Correct  : 2/3
# Time     : 0.000487s
# ------------------------------
# --- Trường hợp #63 ---
# Input    : '489/24A/18 Huỳnh Văn Bánh Phường 13, Phú Nhuận, TP. Hồ Chí Minh'
# Expected : {'province': 'Hồ Chí Minh', 'district': 'Phú Nhuận', 'ward': '13', 'province_normalized': 'Hồ Chí Minh', 'district_normalized': 'Phú Nhuận', 'ward_normalized': '13'}
# Actual   : {'province': 'Hồ Chí Minh', 'district': 'Phú Nhuận', 'ward': '2', 'province_normalized': 'Hồ Chí Minh', 'district_normalized': 'Phú Nhuận', 'ward_normalized': 2}
# Correct  : 2/3
# Time     : 0.000273s
# ------------------------------
# --- Trường hợp #64 ---
# Input    : '285 B/1A Bình Gĩa Phường 8,Vũng Tàu,Bà Rịa - Vũng Tàu'
# Expected : {'province': 'Bà Rịa - Vũng Tàu', 'district': 'Vũng Tàu', 'ward': '8', 'province_normalized': 'Bà Rịa - Vũng Tàu', 'district_normalized': 'Vũng Tàu', 'ward_normalized': 8}
# Actual   : {'province': 'Bà Rịa - Vũng Tàu', 'district': 'Vũng Tàu', 'ward': '2', 'province_normalized': 'Bà Rịa - Vũng Tàu', 'district_normalized': 'Vũng Tàu', 'ward_normalized': 2}
# Correct  : 2/3
# Time     : 0.000376s
# ------------------------------
# --- Trường hợp #68 ---
# Input    : 'Bộ Đầu Thống Nhất, Thường Tín, Hà Nội'
# Expected : {'province': 'Hà Nội', 'district': 'Thường Tín', 'ward': 'Thống Nhất', 'province_normalized': 'Hà Nội', 'district_normalized': 'Thường Tín', 'ward_normalized': 'Thống Nhất'}
# Actual   : {'province': 'Hà Nội', 'district': 'Thường Tín', 'ward': '', 'province_normalized': 'Hà Nội', 'district_normalized': 'Thường Tín', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.000387s
# ------------------------------
# --- Trường hợp #70 ---
# Input    : 'Phố 2, Vân Giang Thành phố Ninh Bình, Ninh Bình'
# Expected : {'province': 'Ninh Bình', 'district': 'Ninh Bình', 'ward': 'Vân Giang', 'province_normalized': 'Ninh Bình', 'district_normalized': 'Ninh Bình', 'ward_normalized': 'Vân Giang'}
# Actual   : {'province': 'An Giang', 'district': '', 'ward': '', 'province_normalized': 'An Giang', 'district_normalized': '', 'ward_normalized': ''}
# Correct  : 0/3
# Time     : 0.001190s
# ------------------------------
# --- Trường hợp #73 ---
# Input    : 'Tổ 11 Sài Đồng, Long Biên, Hà Nội'
# Expected : {'province': 'Hà Nội', 'district': 'Long Biên', 'ward': 'Sài Đồng', 'province_normalized': 'Hà Nội', 'district_normalized': 'Long Biên', 'ward_normalized': 'Sài Đồng'}
# Actual   : {'province': 'Hà Nội', 'district': 'Long Biên', 'ward': '', 'province_normalized': 'Hà Nội', 'district_normalized': 'Long Biên', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.000337s
# ------------------------------
# --- Trường hợp #75 ---
# Input    : 'KP Phước Trung Thị trấn Đất Đỏ, Đất Đỏ, Bà Rịa - Vũng Tàu'
# Expected : {'province': 'Bà Rịa - Vũng Tàu', 'district': 'Đất Đỏ', 'ward': 'Đất Đỏ', 'province_normalized': 'Bà Rịa - Vũng Tàu', 'district_normalized': 'Đất Đỏ', 'ward_normalized': 'Đất Đỏ'}
# Actual   : {'province': 'Bà Rịa - Vũng Tàu', 'district': 'Vũng Tàu', 'ward': '', 'province_normalized': 'Bà Rịa - Vũng Tàu', 'district_normalized': 'Vũng Tàu', 'ward_normalized': ''}
# Correct  : 1/3
# Time     : 0.001081s
# ------------------------------
# --- Trường hợp #76 ---
# Input    : '55/30 Nguyễn - Thượng Hiền,P5,BT, TP. Hồ Chí Minh'
# Expected : {'province': 'Hồ Chí Minh', 'district': 'Bình Thạnh', 'ward': '5', 'province_normalized': 'Hồ Chí Minh', 'district_normalized': 'Bình Thạnh', 'ward_normalized': 5}
# Actual   : {'province': 'Hồ Chí Minh', 'district': '', 'ward': '', 'province_normalized': 'Hồ Chí Minh', 'district_normalized': '', 'ward_normalized': ''}
# Correct  : 1/3
# Time     : 0.001079s
# ------------------------------
# --- Trường hợp #77 ---
# Input    : '290 Tùng Thiện- Vương,P.13, Quận 8, TP. Hồ Chí Minh.'
# Expected : {'province': 'Hồ Chí Minh', 'district': '8', 'ward': '13', 'province_normalized': 'Hồ Chí Minh', 'district_normalized': '8', 'ward_normalized': '13'}
# Actual   : {'province': 'Hồ Chí Minh', 'district': '', 'ward': '', 'province_normalized': 'Hồ Chí Minh', 'district_normalized': '', 'ward_normalized': ''}
# Correct  : 1/3
# Time     : 0.001092s
# ------------------------------
# --- Trường hợp #79 ---
# Input    : '8 Trịnh Văn Cấn P.C-Ô-Lãnh, Q.1, TP. Hồ Chí Minh'
# Expected : {'province': 'Hồ Chí Minh', 'district': '1', 'ward': '', 'province_normalized': 'Hồ Chí Minh', 'district_normalized': '1', 'ward_normalized': ''}
# Actual   : {'province': 'Hồ Chí Minh', 'district': '', 'ward': '', 'province_normalized': 'Hồ Chí Minh', 'district_normalized': '', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.001199s
# ------------------------------
# --- Trường hợp #86 ---
# Input    : 'Khu phố Nam Tân, TT Thuận Nam, Hàm Thuận Bắc, Bình Thuận.'
# Expected : {'province': '', 'district': '', 'ward': '', 'province_normalized': '', 'district_normalized': '', 'ward_normalized': ''}
# Actual   : {'province': 'Bình Thuận', 'district': 'Hàm Thuận Bắc', 'ward': '', 'province_normalized': 'Bình Thuận', 'district_normalized': 'Hàm Thuận Bắc', 'ward_normalized': ''}
# Correct  : 1/3
# Time     : 0.000429s
# ------------------------------
# --- Trường hợp #87 ---
# Input    : '2 dãy C ngõ 16 Ngô Quyền, tổ 14, Quang Trung, Hà Đông, Hà Nội'
# Expected : {'province': 'Hà Nội', 'district': 'Hà Đông', 'ward': 'Quang Trung', 'province_normalized': 'Hà Nội', 'district_normalized': 'Hà Đông', 'ward_normalized': 'Quang Trung'}
# Actual   : {'province': 'Hà Giang', 'district': '', 'ward': '', 'province_normalized': 'Hà Giang', 'district_normalized': '', 'ward_normalized': ''}
# Correct  : 0/3
# Time     : 0.001132s
# ------------------------------
# --- Trường hợp #88 ---
# Input    : 'Sơn Hà Nho Quan, Ninh Bình'
# Expected : {'province': 'Ninh Bình', 'district': 'Nho Quan', 'ward': 'Sơn Hà', 'province_normalized': 'Ninh Bình', 'district_normalized': 'Nho Quan', 'ward_normalized': 'Sơn Hà'}
# Actual   : {'province': 'Ninh Bình', 'district': 'Nho Quan', 'ward': '', 'province_normalized': 'Ninh Bình', 'district_normalized': 'Nho Quan', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.000332s
# ------------------------------
# --- Trường hợp #91 ---
# Input    : 'Xã Nguyên Bình Huyện Tĩnh Gia, Thanh Hoá'
# Expected : {'province': 'Thanh Hóa', 'district': 'Tĩnh Gia', 'ward': 'Nguyên Bình', 'province_normalized': 'Thanh Hóa', 'district_normalized': 'Tĩnh Gia', 'ward_normalized': 'Nguyên Bình'}
# Actual   : {'province': 'Thanh Hóa', 'district': '', 'ward': '', 'province_normalized': 'Thanh Hóa', 'district_normalized': '', 'ward_normalized': ''}
# Correct  : 1/3
# Time     : 0.001486s
# ------------------------------
# --- Trường hợp #93 ---
# Input    : 'Hoằng Minh, Hoằng Hóa Thanh Hóa'
# Expected : {'province': 'Thanh Hóa', 'district': 'Hoằng Hóa', 'ward': 'Hoằng Minh', 'province_normalized': 'Thanh Hóa', 'district_normalized': 'Hoằng Hóa', 'ward_normalized': 'Hoằng Minh'}
# Actual   : {'province': 'Thanh Hóa', 'district': 'Hoằng Hóa', 'ward': '', 'province_normalized': 'Thanh Hóa', 'district_normalized': 'Hoằng Hóa', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.000435s
# ------------------------------
# --- Trường hợp #95 ---
# Input    : 'Liên Bình, Hải Bình Tĩnh Gia, Thanh Hóa'
# Expected : {'province': 'Thanh Hóa', 'district': 'Tĩnh Gia', 'ward': 'Hải Bình', 'province_normalized': 'Thanh Hóa', 'district_normalized': 'Tĩnh Gia', 'ward_normalized': 'Hải Bình'}
# Actual   : {'province': 'Thanh Hóa', 'district': '', 'ward': '', 'province_normalized': 'Thanh Hóa', 'district_normalized': '', 'ward_normalized': ''}
# Correct  : 1/3
# Time     : 0.001205s
# ------------------------------
# --- Trường hợp #100 ---
# Input    : '02 Tú Xương, Đông Thọ Thành phố Thanh Hóa, Thanh Hóa'
# Expected : {'province': 'Thanh Hóa', 'district': 'Thanh Hóa', 'ward': 'Đông Thọ', 'province_normalized': 'Thanh Hóa', 'district_normalized': 'Thanh Hóa', 'ward_normalized': 'Đông Thọ'}
# Actual   : {'province': 'Thanh Hóa', 'district': 'Thạnh Hóa', 'ward': 'Đông Thọ', 'province_normalized': 'Thanh Hóa', 'district_normalized': 'Thạnh Hóa', 'ward_normalized': 'Đông Thọ'}
# Correct  : 2/3
# Time     : 0.000490s
# ------------------------------
# --- Trường hợp #101 ---
# Input    : 'Tân Trung Tân Thành, Tân Châu, Tây Ninh'
# Expected : {'province': 'Tây Ninh', 'district': 'Tân Châu', 'ward': 'Tân Thành', 'province_normalized': 'Tây Ninh', 'district_normalized': 'Tân Châu', 'ward_normalized': 'Tân Thành'}
# Actual   : {'province': 'Tây Ninh', 'district': 'Tân Châu', 'ward': 'Tân Thạnh', 'province_normalized': 'Tây Ninh', 'district_normalized': 'Tân Châu', 'ward_normalized': 'Tân Thạnh'}
# Correct  : 2/3
# Time     : 0.000397s
# ------------------------------
# --- Trường hợp #103 ---
# Input    : '24/98C, Phố Hữu Nghị Xuân Khanh, Sơn Tây, Hà Nội'
# Expected : {'province': 'Hà Nội', 'district': 'Sơn Tây', 'ward': 'Xuân Khanh', 'province_normalized': 'Hà Nội', 'district_normalized': 'Sơn Tây', 'ward_normalized': 'Xuân Khanh'}
# Actual   : {'province': 'Hà Nội', 'district': 'Sơn Tây', 'ward': 'Xuân Khánh', 'province_normalized': 'Hà Nội', 'district_normalized': 'Sơn Tây', 'ward_normalized': 'Xuân Khánh'}
# Correct  : 2/3
# Time     : 0.000371s
# ------------------------------
# --- Trường hợp #105 ---
# Input    : 'Hà Tân Hưng Hà, Tân Hưng, Long An'
# Expected : {'province': 'Long An', 'district': 'Tân Hưng', 'ward': 'Hưng Hà', 'province_normalized': 'Long An', 'district_normalized': 'Tân Hưng', 'ward_normalized': 'Hưng Hà'}
# Actual   : {'province': 'Long An', 'district': 'Tân Hưng', 'ward': 'Tân Hưng', 'province_normalized': 'Long An', 'district_normalized': 'Tân Hưng', 'ward_normalized': 'Tân Hưng'}
# Correct  : 2/3
# Time     : 0.000414s
# ------------------------------
# --- Trường hợp #107 ---
# Input    : '55/21/1 Khu phố 2, Thới An Quận 12, TP. Hồ Chí Minh'
# Expected : {'province': 'Hồ Chí Minh', 'district': '12', 'ward': 'Thới An', 'province_normalized': 'Hồ Chí Minh', 'district_normalized': '12', 'ward_normalized': 'Thới An'}
# Actual   : {'province': 'Hồ Chí Minh', 'district': '', 'ward': '', 'province_normalized': 'Hồ Chí Minh', 'district_normalized': '', 'ward_normalized': ''}
# Correct  : 1/3
# Time     : 0.001050s
# ------------------------------
# --- Trường hợp #109 ---
# Input    : '- Khu B Chu Hoà, Việt HhiPhú Thọ'
# Expected : {'province': '', 'district': '', 'ward': '', 'province_normalized': '', 'district_normalized': '', 'ward_normalized': ''}
# Actual   : {'province': 'Phú Thọ', 'district': 'Phú Thọ', 'ward': '', 'province_normalized': 'Phú Thọ', 'district_normalized': 'Phú Thọ', 'ward_normalized': ''}
# Correct  : 1/3
# Time     : 0.000942s
# ------------------------------
# --- Trường hợp #111 ---
# Input    : 'Số 7/Q3, KPI, Phường Long Bình Tân, Tp Biên Hoà, Đồng Nai.'
# Expected : {'province': 'Đồng Nai', 'district': 'Biên Hòa', 'ward': 'Long Bình Tân', 'province_normalized': 'Đồng Nai', 'district_normalized': 'Biên Hòa', 'ward_normalized': 'Long Bình Tân'}
# Actual   : {'province': 'Đồng Nai', 'district': 'Biên Hòa', 'ward': 'Long Bình', 'province_normalized': 'Đồng Nai', 'district_normalized': 'Biên Hòa', 'ward_normalized': 'Long Bình'}
# Correct  : 2/3
# Time     : 0.000401s
# ------------------------------
# --- Trường hợp #112 ---
# Input    : 'Khu 1, Trung Giáp, Phù Ninh, Phú Thọ.'
# Expected : {'province': 'Phú Thọ', 'district': 'Phù Ninh', 'ward': 'Trung Giáp', 'province_normalized': 'Phú Thọ', 'district_normalized': 'Phù Ninh', 'ward_normalized': 'Trung Giáp'}
# Actual   : {'province': 'Phú Thọ', 'district': 'Phú Ninh', 'ward': 'Trung Giáp', 'province_normalized': 'Phú Thọ', 'district_normalized': 'Phú Ninh', 'ward_normalized': 'Trung Giáp'}
# Correct  : 2/3
# Time     : 0.000381s
# ------------------------------
# --- Trường hợp #113 ---
# Input    : 'A:12A.21BlockA C/c BCA,P.AnKhánh,TP.Thủ Đức, TP. HCM'
# Expected : {'province': 'Hồ Chí Minh', 'district': 'Thủ Đức', 'ward': '', 'province_normalized': 'Hồ Chí Minh', 'district_normalized': 'Thủ Đức', 'ward_normalized': ''}
# Actual   : {'province': 'Bình Định', 'district': '', 'ward': '', 'province_normalized': 'Bình Định', 'district_normalized': '', 'ward_normalized': ''}
# Correct  : 1/3
# Time     : 0.001163s
# ------------------------------
# --- Trường hợp #114 ---
# Input    : 'L10C12 Hẻm 90, Ng, Bỉnh Khiêm, TP. Rạch Giá, Kiên Giang'
# Expected : {'province': 'Kiên Giang', 'district': '', 'ward': '', 'province_normalized': 'Kiên Giang', 'district_normalized': '', 'ward_normalized': ''}
# Actual   : {'province': 'Kiên Giang', 'district': 'Rạch Giá', 'ward': '', 'province_normalized': 'Kiên Giang', 'district_normalized': 'Rạch Giá', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.000354s
# ------------------------------
# --- Trường hợp #116 ---
# Input    : '51 Phạm Ngũ Lão, Lê Lợi Sơn Tây, Hà Nội'
# Expected : {'province': 'Hà Nội', 'district': 'Sơn Tây', 'ward': 'Lê Lợi', 'province_normalized': 'Hà Nội', 'district_normalized': 'Sơn Tây', 'ward_normalized': 'Lê Lợi'}
# Actual   : {'province': 'Hà Nội', 'district': 'Sơn Tây', 'ward': '', 'province_normalized': 'Hà Nội', 'district_normalized': 'Sơn Tây', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.000354s
# ------------------------------
# --- Trường hợp #118 ---
# Input    : 'Mỹ Phú 5 Tường Lộc, Tam Bình, Vĩnh Long'
# Expected : {'province': 'Vĩnh Long', 'district': 'Tam Bình', 'ward': 'Tường Lộc', 'province_normalized': 'Vĩnh Long', 'district_normalized': 'Tam Bình', 'ward_normalized': 'Tường Lộc'}
# Actual   : {'province': 'Vĩnh Long', 'district': 'Tam Bình', 'ward': '', 'province_normalized': 'Vĩnh Long', 'district_normalized': 'Tam Bình', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.000344s
# ------------------------------
# --- Trường hợp #123 ---
# Input    : '14.5 Block A2, The Mansion, ĐS 7,KDC 13E,Ấp 5,PP,BC, TP.HCM'
# Expected : {'province': 'Hồ Chí Minh', 'district': '', 'ward': '', 'province_normalized': 'Hồ Chí Minh', 'district_normalized': '', 'ward_normalized': ''}
# Actual   : {'province': 'Bình Định', 'district': '', 'ward': '', 'province_normalized': 'Bình Định', 'district_normalized': '', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.000926s
# ------------------------------
# --- Trường hợp #124 ---
# Input    : 'Xã Yên Sơn, Huyện Lục Nam, Tỉnh Bắc Giang'
# Expected : {'province': 'Bắc Giang', 'district': 'Lục Nam', 'ward': 'Yên Sơn', 'province_normalized': 'Bắc Giang', 'district_normalized': 'Lục Nam', 'ward_normalized': 'Yên Sơn'}
# Actual   : {'province': 'Bắc Giang', 'district': 'Lục Nam', 'ward': 'Yến Sơn', 'province_normalized': 'Bắc Giang', 'district_normalized': 'Lục Nam', 'ward_normalized': 'Yến Sơn'}
# Correct  : 2/3
# Time     : 0.000311s
# ------------------------------
# --- Trường hợp #125 ---
# Input    : '161/18A Cô Giang, Cô Giang Quận 1, TP. Hồ Chí Minh'
# Expected : {'province': 'Hồ Chí Minh', 'district': '1', 'ward': 'Cô Giang', 'province_normalized': 'Hồ Chí Minh', 'district_normalized': '1', 'ward_normalized': 'Cô Giang'}
# Actual   : {'province': 'Hồ Chí Minh', 'district': '', 'ward': '', 'province_normalized': 'Hồ Chí Minh', 'district_normalized': '', 'ward_normalized': ''}
# Correct  : 1/3
# Time     : 0.001124s
# ------------------------------
# --- Trường hợp #128 ---
# Input    : 'Phố Tân Mỹ Thị trấn Me, Gia Viễn, Ninh Bình'
# Expected : {'province': 'Ninh Bình', 'district': 'Gia Viễn', 'ward': 'Me', 'province_normalized': 'Ninh Bình', 'district_normalized': 'Gia Viễn', 'ward_normalized': 'Me'}
# Actual   : {'province': 'Ninh Bình', 'district': 'Gia Viễn', 'ward': '', 'province_normalized': 'Ninh Bình', 'district_normalized': 'Gia Viễn', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.000365s
# ------------------------------
# --- Trường hợp #131 ---
# Input    : '31B Sư Vạn Hạnh, Phường 3 Quận 10, TP. Hồ Chí Minh'
# Expected : {'province': 'Hồ Chí Minh', 'district': '10', 'ward': '3', 'province_normalized': 'Hồ Chí Minh', 'district_normalized': '10', 'ward_normalized': 3}
# Actual   : {'province': 'Hồ Chí Minh', 'district': '', 'ward': '', 'province_normalized': 'Hồ Chí Minh', 'district_normalized': '', 'ward_normalized': ''}
# Correct  : 1/3
# Time     : 0.001083s
# ------------------------------
# --- Trường hợp #133 ---
# Input    : 'Số 10, Ngách 43/3, Ngõ 43 Nguyễn Ngọc Nại, Khương Mai, Thanh Xuân, Hà Nội.'
# Expected : {'province': 'Hà Nội', 'district': 'Thanh Xuân', 'ward': 'Khương Mai', 'province_normalized': 'Hà Nội', 'district_normalized': 'Thanh Xuân', 'ward_normalized': 'Khương Mai'}
# Actual   : {'province': 'Hà Nội', 'district': 'Thanh Xuân', 'ward': '', 'province_normalized': 'Hà Nội', 'district_normalized': 'Thanh Xuân', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.000626s
# ------------------------------
# --- Trường hợp #134 ---
# Input    : '191A Nguyễn Thị Định An Phú, Quận 2, Tp Hồ Chí Minh'
# Expected : {'province': 'Hồ Chí Minh', 'district': '2', 'ward': 'An Phú', 'province_normalized': 'Hồ Chí Minh', 'district_normalized': '2', 'ward_normalized': 'An Phú'}
# Actual   : {'province': 'Hồ Chí Minh', 'district': '', 'ward': '', 'province_normalized': 'Hồ Chí Minh', 'district_normalized': '', 'ward_normalized': ''}
# Correct  : 1/3
# Time     : 0.001093s
# ------------------------------
# --- Trường hợp #139 ---
# Input    : 'Số 1410 Đường 30/4, Phường 12, Thành phố Vũng Tàu, Bà Rịa - Vũng Tàu.'
# Expected : {'province': 'Bà Rịa - Vũng Tàu', 'district': 'Vũng Tàu', 'ward': '12', 'province_normalized': 'Bà Rịa - Vũng Tàu', 'district_normalized': 'Vũng Tàu', 'ward_normalized': '12'}
# Actual   : {'province': 'Bà Rịa - Vũng Tàu', 'district': 'Vũng Tàu', 'ward': '2', 'province_normalized': 'Bà Rịa - Vũng Tàu', 'district_normalized': 'Vũng Tàu', 'ward_normalized': 2}
# Correct  : 2/3
# Time     : 0.000424s
# ------------------------------
# --- Trường hợp #143 ---
# Input    : 'Phường Lê Hồng Phong Tp. Quy Nhơn, tỉnh Bình Định.'
# Expected : {'province': 'Bình Định', 'district': 'Quy Nhơn', 'ward': 'Lê Hồng Phong', 'province_normalized': 'Bình Định', 'district_normalized': 'quy nhơn', 'ward_normalized': 'Lê Hồng Phong'}
# Actual   : {'province': 'Bình Định', 'district': 'Quy Nhơn', 'ward': '', 'province_normalized': 'Bình Định', 'district_normalized': 'quy nhơn', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.000466s
# ------------------------------
# --- Trường hợp #144 ---
# Input    : '7/3/4/16 Thành Thái Phường 14, Quận 10, TP. Hồ Chí Minh'
# Expected : {'province': 'Hồ Chí Minh', 'district': '10', 'ward': '14', 'province_normalized': 'Hồ Chí Minh', 'district_normalized': '10', 'ward_normalized': '14'}
# Actual   : {'province': 'Hồ Chí Minh', 'district': '', 'ward': '', 'province_normalized': 'Hồ Chí Minh', 'district_normalized': '', 'ward_normalized': ''}
# Correct  : 1/3
# Time     : 0.000959s
# ------------------------------
# --- Trường hợp #146 ---
# Input    : 'Quang Xá, Quang Hưng, Phù Cừ, Hưng Yên'
# Expected : {'province': 'Hưng Yên', 'district': 'Phù Cừ', 'ward': 'Quang Hưng', 'province_normalized': 'Hưng Yên', 'district_normalized': 'Phù Cừ', 'ward_normalized': 'Quang Hưng'}
# Actual   : {'province': 'Hưng Yên', 'district': 'Phù Cừ', 'ward': 'Quảng Hưng', 'province_normalized': 'Hưng Yên', 'district_normalized': 'Phù Cừ', 'ward_normalized': 'Quảng Hưng'}
# Correct  : 2/3
# Time     : 0.000397s
# ------------------------------
# --- Trường hợp #149 ---
# Input    : '820/12 Hậu Giang, Phường 12 Quận 6, TP. Hồ Chí Minh'
# Expected : {'province': 'Hồ Chí Minh', 'district': '6', 'ward': '12', 'province_normalized': 'Hồ Chí Minh', 'district_normalized': '6', 'ward_normalized': '12'}
# Actual   : {'province': 'Hậu Giang', 'district': '', 'ward': '', 'province_normalized': 'Hậu Giang', 'district_normalized': '', 'ward_normalized': ''}
# Correct  : 0/3
# Time     : 0.001163s
# ------------------------------
# --- Trường hợp #151 ---
# Input    : 'Liên Minh,,TỉnhThái Nguyên'
# Expected : {'district': '', 'ward': 'Liên Minh', 'province': 'Thái Nguyên', 'province_normalized': 'Thái Nguyên', 'district_normalized': '', 'ward_normalized': 'Liên Minh'}
# Actual   : {'province': 'Thái Nguyên', 'district': 'Thái Nguyên', 'ward': '', 'province_normalized': 'Thái Nguyên', 'district_normalized': 'Thái Nguyên', 'ward_normalized': ''}
# Correct  : 1/3
# Time     : 0.000909s
# ------------------------------
# --- Trường hợp #154 ---
# Input    : ' Chợ Chu, , T Thái Nguyên'
# Expected : {'district': '', 'ward': 'Chợ Chu', 'province': 'Thái Nguyên', 'province_normalized': 'Thái Nguyên', 'district_normalized': '', 'ward_normalized': 'Chợ Chu'}
# Actual   : {'province': 'Thái Nguyên', 'district': 'Thái Nguyên', 'ward': '', 'province_normalized': 'Thái Nguyên', 'district_normalized': 'Thái Nguyên', 'ward_normalized': ''}
# Correct  : 1/3
# Time     : 0.000870s
# ------------------------------
# --- Trường hợp #155 ---
# Input    : 'Hải Ba  Hải Lăng '
# Expected : {'district': 'Hải Lăng', 'ward': 'Hải Ba', 'province': '', 'province_normalized': '', 'district_normalized': 'Hải Lăng', 'ward_normalized': 'Hải Ba'}
# Actual   : {'province': 'Hải Dương', 'district': '', 'ward': '', 'province_normalized': 'Hải Dương', 'district_normalized': '', 'ward_normalized': ''}
# Correct  : 0/3
# Time     : 0.000978s
# ------------------------------
# --- Trường hợp #157 ---
# Input    : 'Phường Phú Lợi  TBình Dương'
# Expected : {'district': '', 'ward': 'Phú Lợi', 'province': 'Bình Dương', 'province_normalized': 'Bình Dương', 'district_normalized': '', 'ward_normalized': 'Phú Lợi'}
# Actual   : {'province': 'Bình Dương', 'district': '', 'ward': '', 'province_normalized': 'Bình Dương', 'district_normalized': '', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.000946s
# ------------------------------
# --- Trường hợp #160 ---
# Input    : 'X. Trà Sơn,Huyện Trà Bồng,T.Quảng mNgãi'
# Expected : {'district': 'Trà Bồng', 'ward': 'Trà Sơn', 'province': 'Quảng Ngãi', 'province_normalized': 'Quảng Ngãi', 'district_normalized': 'Trà Bồng', 'ward_normalized': 'Trà Sơn'}
# Actual   : {'province': 'Quảng Ngãi', 'district': 'Trà Bồng', 'ward': '', 'province_normalized': 'Quảng Ngãi', 'district_normalized': 'Trà Bồng', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.001096s
# ------------------------------
# --- Trường hợp #162 ---
# Input    : 'Van Điểm, H hường TLín, Thành phốHa Nội'
# Expected : {'district': 'Thường Tín', 'ward': 'Vạn Điểm', 'province': 'Hà Nội', 'province_normalized': 'Hà Nội', 'district_normalized': 'Thường Tín', 'ward_normalized': 'Vạn Điểm'}
# Actual   : {'province': 'Hà Nội', 'district': '', 'ward': '', 'province_normalized': 'Hà Nội', 'district_normalized': '', 'ward_normalized': ''}
# Correct  : 1/3
# Time     : 0.001124s
# ------------------------------
# --- Trường hợp #164 ---
# Input    : 'XThạnh Đức, HGò Dầ6u, T Tây Ninh'
# Expected : {'district': 'Gò Dầu', 'ward': 'Thạnh Đức', 'province': 'Tây Ninh', 'province_normalized': 'Tây Ninh', 'district_normalized': 'Gò Dầu', 'ward_normalized': 'Thạnh Đức'}
# Actual   : {'province': 'Tây Ninh', 'district': 'Tây Ninh', 'ward': '', 'province_normalized': 'Tây Ninh', 'district_normalized': 'Tây Ninh', 'ward_normalized': ''}
# Correct  : 1/3
# Time     : 0.000969s
# ------------------------------
# --- Trường hợp #165 ---
# Input    : 'X.Thài Phìn Tủng, Huyện ĐồGg Van,  Hà Gxiang'
# Expected : {'district': 'Đồng Văn', 'ward': 'Thài Phìn Tủng', 'province': 'Hà Giang', 'province_normalized': 'Hà Giang', 'district_normalized': 'Đồng Văn', 'ward_normalized': 'Thài Phìn Tủng'}
# Actual   : {'province': 'Hà Giang', 'district': '', 'ward': '', 'province_normalized': 'Hà Giang', 'district_normalized': '', 'ward_normalized': ''}
# Correct  : 1/3
# Time     : 0.001136s
# ------------------------------
# --- Trường hợp #166 ---
# Input    : 'XãBù Gia Mập,,T Bình Phước'
# Expected : {'district': '', 'ward': 'Bù Gia Mập', 'province': 'Bình Phước', 'province_normalized': 'Bình Phước', 'district_normalized': '', 'ward_normalized': 'Bù Gia Mập'}
# Actual   : {'province': 'Bình Phước', 'district': 'Bù Gia Mập', 'ward': '', 'province_normalized': 'Bình Phước', 'district_normalized': 'Bù Gia Mập', 'ward_normalized': ''}
# Correct  : 1/3
# Time     : 0.000310s
# ------------------------------
# --- Trường hợp #167 ---
# Input    : 'Xã Mỹ Lương Yên Lập '
# Expected : {'district': 'Yên Lập', 'ward': 'Mỹ Lương', 'province': '', 'province_normalized': '', 'district_normalized': 'Yên Lập', 'ward_normalized': 'Mỹ Lương'}
# Actual   : {'province': 'Hưng Yên', 'district': '', 'ward': '', 'province_normalized': 'Hưng Yên', 'district_normalized': '', 'ward_normalized': ''}
# Correct  : 0/3
# Time     : 0.000806s
# ------------------------------
# --- Trường hợp #168 ---
# Input    : ',H.Nqm Đàn, nghệ An'
# Expected : {'district': 'Nam Đàn', 'ward': '', 'province': 'Nghệ An', 'province_normalized': 'Nghệ An', 'district_normalized': 'Nam Đàn', 'ward_normalized': ''}
# Actual   : {'province': 'Nghệ An', 'district': '', 'ward': '', 'province_normalized': 'Nghệ An', 'district_normalized': '', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.000950s
# ------------------------------
# --- Trường hợp #172 ---
# Input    : 'Xã La Dêê  Quảng Nam'
# Expected : {'district': '', 'ward': 'La Dêê', 'province': 'Quảng Nam', 'province_normalized': 'Quảng Nam', 'district_normalized': '', 'ward_normalized': 'La Dêê'}
# Actual   : {'province': 'Quảng Nam', 'district': '', 'ward': '', 'province_normalized': 'Quảng Nam', 'district_normalized': '', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.001108s
# ------------------------------
# --- Trường hợp #173 ---
# Input    : 'XTân Thạnh, hAn Minh '
# Expected : {'district': 'An Minh', 'ward': 'Tân Thạnh', 'province': '', 'province_normalized': '', 'district_normalized': 'An Minh', 'ward_normalized': 'Tân Thạnh'}
# Actual   : {'province': 'Hồ Chí Minh', 'district': '', 'ward': '', 'province_normalized': 'Hồ Chí Minh', 'district_normalized': '', 'ward_normalized': ''}
# Correct  : 0/3
# Time     : 0.001622s
# ------------------------------
# --- Trường hợp #174 ---
# Input    : 'X Cam Bình, Thành FhốCam Rah,  Khánh Hòa'
# Expected : {'district': 'Cam Ranh', 'ward': 'Cam Bình', 'province': 'Khánh Hòa', 'province_normalized': 'Khánh Hòa', 'district_normalized': 'Cam Ranh', 'ward_normalized': 'Cam Bình'}
# Actual   : {'province': 'Khánh Hòa', 'district': '', 'ward': '', 'province_normalized': 'Khánh Hòa', 'district_normalized': '', 'ward_normalized': ''}
# Correct  : 1/3
# Time     : 0.001975s
# ------------------------------
# --- Trường hợp #175 ---
# Input    : 'X.UThạnh Lợi  TỉnhLong An'
# Expected : {'district': '', 'ward': 'Thạnh Lợi', 'province': 'Long An', 'province_normalized': 'Long An', 'district_normalized': '', 'ward_normalized': 'Thạnh Lợi'}
# Actual   : {'province': 'Long An', 'district': '', 'ward': '', 'province_normalized': 'Long An', 'district_normalized': '', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.001787s
# ------------------------------
# --- Trường hợp #176 ---
# Input    : ' Minh Tân,h.Lưng Tai,'
# Expected : {'district': 'Lương Tài', 'ward': 'Minh Tân', 'province': '', 'province_normalized': '', 'district_normalized': 'Lương Tài', 'ward_normalized': 'Minh Tân'}
# Actual   : {'province': 'Hồ Chí Minh', 'district': '', 'ward': '', 'province_normalized': 'Hồ Chí Minh', 'district_normalized': '', 'ward_normalized': ''}
# Correct  : 0/3
# Time     : 0.001664s
# ------------------------------
# --- Trường hợp #177 ---
# Input    : 'XãQuỳn1 Lâm, H. Quỳnh Phụ,  Thai Bình'
# Expected : {'district': 'Quỳnh Phụ', 'ward': 'Quỳnh Lâm', 'province': 'Thái Bình', 'province_normalized': 'Thái Bình', 'district_normalized': 'Quỳnh Phụ', 'ward_normalized': 'Quỳnh Lâm'}
# Actual   : {'province': 'Thái Bình', 'district': 'Quỳnh Phụ', 'ward': '', 'province_normalized': 'Thái Bình', 'district_normalized': 'Quỳnh Phụ', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.000652s
# ------------------------------
# --- Trường hợp #178 ---
# Input    : 'X.Nà Tấu, , T.Điện Biên'
# Expected : {'district': '', 'ward': 'Nà Tấu', 'province': 'Điện Biên', 'province_normalized': 'Điện Biên', 'district_normalized': '', 'ward_normalized': 'Nà Tấu'}
# Actual   : {'province': 'Điện Biên', 'district': 'Điện Biên', 'ward': '', 'province_normalized': 'Điện Biên', 'district_normalized': 'Điện Biên', 'ward_normalized': ''}
# Correct  : 1/3
# Time     : 0.001627s
# ------------------------------
# --- Trường hợp #189 ---
# Input    : 'Sơn Thủy T Quảng Bình'
# Expected : {'district': '', 'ward': 'Sơn Thủy', 'province': 'Quảng Bình', 'province_normalized': 'Quảng Bình', 'district_normalized': '', 'ward_normalized': 'Sơn Thủy'}
# Actual   : {'province': 'Quảng Bình', 'district': '', 'ward': '', 'province_normalized': 'Quảng Bình', 'district_normalized': '', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.001629s
# ------------------------------
# --- Trường hợp #191 ---
# Input    : 'Xan Tiến, H. An Lão, '
# Expected : {'district': 'An Lão', 'ward': 'An Tiến', 'province': '', 'province_normalized': '', 'district_normalized': 'An Lão', 'ward_normalized': 'An Tiến'}
# Actual   : {'province': 'An Giang', 'district': '', 'ward': '', 'province_normalized': 'An Giang', 'district_normalized': '', 'ward_normalized': ''}
# Correct  : 0/3
# Time     : 0.001728s
# ------------------------------
# --- Trường hợp #192 ---
# Input    : 'XGia Hội,h.Văn Chấn,TỉnhYênKBái'
# Expected : {'district': 'Văn Chấn', 'ward': 'Gia Hội', 'province': 'Yên Bái', 'province_normalized': 'Yên Bái', 'district_normalized': 'Văn Chấn', 'ward_normalized': 'Gia Hội'}
# Actual   : {'province': 'Yên Bái', 'district': 'Văn Chấn', 'ward': '', 'province_normalized': 'Yên Bái', 'district_normalized': 'Văn Chấn', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.001828s
# ------------------------------
# --- Trường hợp #194 ---
# Input    : 'X. HoDng Quỳ,,9hanh Hóa'
# Expected : {'district': '', 'ward': 'Hoằng Quỳ', 'province': 'Thanh Hóa', 'province_normalized': 'Thanh Hóa', 'district_normalized': '', 'ward_normalized': 'Hoằng Quỳ'}
# Actual   : {'province': 'Hoà Bình', 'district': '', 'ward': '', 'province_normalized': 'Hoà Bình', 'district_normalized': '', 'ward_normalized': ''}
# Correct  : 1/3
# Time     : 0.001539s
# ------------------------------
# --- Trường hợp #196 ---
# Input    : 'X.Tân Tiến,H.Đồng Phú,'
# Expected : {'district': 'Đồng Phú', 'ward': 'Tân Tiến', 'province': '', 'province_normalized': '', 'district_normalized': 'Đồng Phú', 'ward_normalized': 'Tân Tiến'}
# Actual   : {'province': 'Lâm Đồng', 'district': '', 'ward': '', 'province_normalized': 'Lâm Đồng', 'district_normalized': '', 'ward_normalized': ''}
# Correct  : 0/3
# Time     : 0.001752s
# ------------------------------
# --- Trường hợp #197 ---
# Input    : 'FHim Lam   Điện Biê'
# Expected : {'district': '', 'ward': 'Him Lam', 'province': 'Điện Biên', 'province_normalized': 'Điện Biên', 'district_normalized': '', 'ward_normalized': 'Him Lam'}
# Actual   : {'province': 'Lâm Đồng', 'district': '', 'ward': '', 'province_normalized': 'Lâm Đồng', 'district_normalized': '', 'ward_normalized': ''}
# Correct  : 1/3
# Time     : 0.001520s
# ------------------------------
# --- Trường hợp #198 ---
# Input    : 'PHoà Quý Q.ngũ Hành sơn Đà Nẵng'
# Expected : {'district': 'Ngũ Hành Sơn', 'ward': 'Hoà Quý', 'province': 'Đà Nẵng', 'province_normalized': 'Đà Nẵng', 'district_normalized': 'Ngũ Hành Sơn', 'ward_normalized': 'Hoà Quý'}
# Actual   : {'province': 'Đà Nẵng', 'district': 'Ngũ Hành Sơn', 'ward': 'Hóa Quỳ', 'province_normalized': 'Đà Nẵng', 'district_normalized': 'Ngũ Hành Sơn', 'ward_normalized': 'Hóa Quỳ'}
# Correct  : 2/3
# Time     : 0.000648s
# ------------------------------
# --- Trường hợp #199 ---
# Input    : ' BảIn Sen H Mường Khương T5Lào Cai'
# Expected : {'district': 'Mường Khương', 'ward': 'Bản Sen', 'province': 'Lào Cai', 'province_normalized': 'Lào Cai', 'district_normalized': 'Mường Khương', 'ward_normalized': 'Bản Sen'}
# Actual   : {'province': 'Lào Cai', 'district': 'Mường Khương', 'ward': '', 'province_normalized': 'Lào Cai', 'district_normalized': 'Mường Khương', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.000533s
# ------------------------------
# --- Trường hợp #201 ---
# Input    : 'XãV Ninh, Kiên Xương,'
# Expected : {'district': 'Kiến Xương', 'ward': 'Vũ Ninh', 'province': '', 'province_normalized': '', 'district_normalized': 'Kiến Xương', 'ward_normalized': 'Vũ Ninh'}
# Actual   : {'province': 'Bắc Ninh', 'district': '', 'ward': '', 'province_normalized': 'Bắc Ninh', 'district_normalized': '', 'ward_normalized': ''}
# Correct  : 0/3
# Time     : 0.001591s
# ------------------------------
# --- Trường hợp #203 ---
# Input    : 'X. Trà DVưong Bắc Trà My TQuảg Nam'
# Expected : {'district': 'Bắc Trà My', 'ward': 'Trà Dương', 'province': 'Quảng Nam', 'province_normalized': 'Quảng Nam', 'district_normalized': 'Bắc Trà My', 'ward_normalized': 'Trà Dương'}
# Actual   : {'province': 'Quảng Nam', 'district': 'Bắc Trà My', 'ward': '', 'province_normalized': 'Quảng Nam', 'district_normalized': 'Bắc Trà My', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.001957s
# ------------------------------
# --- Trường hợp #206 ---
# Input    : 'X.Thiết Kế,H.Bá Thước,'
# Expected : {'district': 'Bá Thước', 'ward': 'Thiết Kế', 'province': '', 'province_normalized': '', 'district_normalized': 'Bá Thước', 'ward_normalized': 'Thiết Kế'}
# Actual   : {'province': 'Bà Rịa - Vũng Tàu', 'district': '', 'ward': '', 'province_normalized': 'Bà Rịa - Vũng Tàu', 'district_normalized': '', 'ward_normalized': ''}
# Correct  : 0/3
# Time     : 0.001637s
# ------------------------------
# --- Trường hợp #207 ---
# Input    : 'Phưng Khâm Thiên Quận Đ.Đa T.Phố HàNội'
# Expected : {'district': 'Đống Đa', 'ward': 'Khâm Thiên', 'province': 'Hà Nội', 'province_normalized': 'Hà Nội', 'district_normalized': 'Đống Đa', 'ward_normalized': 'Khâm Thiên'}
# Actual   : {'province': 'Thừa Thiên Huế', 'district': '', 'ward': '', 'province_normalized': 'Thừa Thiên Huế', 'district_normalized': '', 'ward_normalized': ''}
# Correct  : 0/3
# Time     : 0.001553s
# ------------------------------
# --- Trường hợp #208 ---
# Input    : 'X Quỳnh Nuyên,,T. Thái Bình'
# Expected : {'district': '', 'ward': 'Quỳnh Nguyên', 'province': 'Thái Bình', 'province_normalized': 'Thái Bình', 'district_normalized': '', 'ward_normalized': 'Quỳnh Nguyên'}
# Actual   : {'province': 'Thái Bình', 'district': 'Thái Bình', 'ward': '', 'province_normalized': 'Thái Bình', 'district_normalized': 'Thái Bình', 'ward_normalized': ''}
# Correct  : 1/3
# Time     : 0.001078s
# ------------------------------
# --- Trường hợp #209 ---
# Input    : 'XVnh Hung, , T.Thanh Hóa'
# Expected : {'district': '', 'ward': 'Vĩnh Hùng', 'province': 'Thanh Hóa', 'province_normalized': 'Thanh Hóa', 'district_normalized': '', 'ward_normalized': 'Vĩnh Hùng'}
# Actual   : {'province': 'Thanh Hóa', 'district': '', 'ward': '', 'province_normalized': 'Thanh Hóa', 'district_normalized': '', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.000982s
# ------------------------------
# --- Trường hợp #210 ---
# Input    : 'X.Tăng Thanh, H Yên Thành, '
# Expected : {'district': 'Yên Thành', 'ward': 'Tăng Thành', 'province': '', 'province_normalized': '', 'district_normalized': 'Yên Thành', 'ward_normalized': 'Tăng Thành'}
# Actual   : {'province': 'Nghệ An', 'district': 'Yên Thành', 'ward': '', 'province_normalized': 'Nghệ An', 'district_normalized': 'Yên Thành', 'ward_normalized': ''}
# Correct  : 1/3
# Time     : 0.001132s
# ------------------------------
# --- Trường hợp #211 ---
# Input    : 'XãTrung Lập,  Vĩnh Bảo,7 '
# ...
# Correct  : 0/3
# Time     : 0.002218s
# ------------------------------
# --- Trường hợp #386 ---
# Input    : 'X. Bản Nguyen,HuyệnLâm Thao,'
# Expected : {'district': 'Lâm Thao', 'ward': 'Bản Nguyên', 'province': '', 'province_normalized': '', 'district_normalized': 'Lâm Thao', 'ward_normalized': 'Bản Nguyên'}
# Actual   : {'province': 'Đà Nẵng', 'district': '', 'ward': '', 'province_normalized': 'Đà Nẵng', 'district_normalized': '', 'ward_normalized': ''}
# Correct  : 0/3
# Time     : 0.001604s
# ------------------------------
# --- Trường hợp #387 ---
# Input    : 'Phương Công,huyen Tiền Hải,T.Thái Bình'
# Expected : {'district': 'Tiền Hải', 'ward': 'Phương Công', 'province': 'Thái Bình', 'province_normalized': 'Thái Bình', 'district_normalized': 'Tiền Hải', 'ward_normalized': 'Phương Công'}
# Actual   : {'province': 'Thái Bình', 'district': 'Tiền Hải', 'ward': 'Đông Cơ', 'province_normalized': 'Thái Bình', 'district_normalized': 'Tiền Hải', 'ward_normalized': 'Đông Cơ'}
# Correct  : 2/3
# Time     : 0.000567s
# ------------------------------
# --- Trường hợp #390 ---
# Input    : 'Xã Kiên Thành H Trấn Yên T.yên Bi'
# Expected : {'district': 'Trấn Yên', 'ward': 'Kiên Thành', 'province': 'Yên Bái', 'province_normalized': 'Yên Bái', 'district_normalized': 'Trấn Yên', 'ward_normalized': 'Kiên Thành'}
# Actual   : {'province': 'Yên Bái', 'district': 'Trấn Yên', 'ward': '', 'province_normalized': 'Yên Bái', 'district_normalized': 'Trấn Yên', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.001814s
# ------------------------------
# --- Trường hợp #394 ---
# Input    : ' Quận 1 T.P H.C.Minh'
# Expected : {'district': '1', 'ward': '', 'province': 'Hồ Chí Minh', 'province_normalized': 'Hồ Chí Minh', 'district_normalized': '1', 'ward_normalized': ''}
# Actual   : {'province': 'Đà Nẵng', 'district': '', 'ward': '', 'province_normalized': 'Đà Nẵng', 'district_normalized': '', 'ward_normalized': ''}
# Correct  : 1/3
# Time     : 0.001595s
# ------------------------------
# --- Trường hợp #396 ---
# Input    : 'XDuy Hải  TQuảng Nam'
# Expected : {'district': '', 'ward': 'Duy Hải', 'province': 'Quảng Nam', 'province_normalized': 'Quảng Nam', 'district_normalized': '', 'ward_normalized': 'Duy Hải'}
# Actual   : {'province': 'Quảng Nam', 'district': '', 'ward': '', 'province_normalized': 'Quảng Nam', 'district_normalized': '', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.001615s
# ------------------------------
# --- Trường hợp #398 ---
# Input    : 'x. Văn Cẩs HuyệnHung Hà Tthái Bình'
# Expected : {'district': 'Hưng Hà', 'ward': 'Văn Cẩm', 'province': 'Thái Bình', 'province_normalized': 'Thái Bình', 'district_normalized': 'Hưng Hà', 'ward_normalized': 'Văn Cẩm'}
# Actual   : {'province': 'Thái Bình', 'district': 'Hưng Hà', 'ward': '', 'province_normalized': 'Thái Bình', 'district_normalized': 'Hưng Hà', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.000613s
# ------------------------------
# --- Trường hợp #400 ---
# Input    : 'oã Bnh Ngọc,T.Phố Tuy Hoà,Tỉnhphú Yên'
# Expected : {'district': 'Tuy Hoà', 'ward': 'Bình Ngọc', 'province': 'Phú Yên', 'province_normalized': 'Phú Yên', 'district_normalized': 'Tuy Hoà', 'ward_normalized': 'Bình Ngọc'}
# Actual   : {'province': 'Phú Yên', 'district': 'Tuy Hoà', 'ward': '', 'province_normalized': 'Phú Yên', 'district_normalized': 'Tuy Hoà', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.000552s
# ------------------------------
# --- Trường hợp #401 ---
# Input    : ' Chương Dương, HuyệnĐôngHưng, '
# Expected : {'district': 'Đông Hưng', 'ward': 'Chương Dương', 'province': '', 'province_normalized': '', 'district_normalized': 'Đông Hưng', 'ward_normalized': 'Chương Dương'}
# Actual   : {'province': 'Bình Dương', 'district': '', 'ward': '', 'province_normalized': 'Bình Dương', 'district_normalized': '', 'ward_normalized': ''}
# Correct  : 0/3
# Time     : 0.001598s
# ------------------------------
# --- Trường hợp #402 ---
# Input    : 'Nậm Tin  Diện Biên'
# Expected : {'district': '', 'ward': 'Nậm Tin', 'province': 'Điện Biên', 'province_normalized': 'Điện Biên', 'district_normalized': '', 'ward_normalized': 'Nậm Tin'}
# Actual   : {'province': 'Điện Biên', 'district': 'Điện Biên', 'ward': '', 'province_normalized': 'Điện Biên', 'district_normalized': 'Điện Biên', 'ward_normalized': ''}
# Correct  : 1/3
# Time     : 0.001517s
# ------------------------------
# --- Trường hợp #403 ---
# Input    : ' T.P Phan Rang-Tháp lhàm  Ninh Thuận'
# Expected : {'district': 'Phan Rang-Tháp Chàm', 'ward': '', 'province': 'Ninh Thuận', 'province_normalized': 'Ninh Thuận', 'district_normalized': 'Phan Rang-Tháp Chàm', 'ward_normalized': ''}
# Actual   : {'province': 'Ninh Thuận', 'district': '', 'ward': '', 'province_normalized': 'Ninh Thuận', 'district_normalized': '', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.001859s
# ------------------------------
# --- Trường hợp #404 ---
# Input    : ', Tân Phươc, Tin GJiang'
# Expected : {'district': 'Tân Phước', 'ward': '', 'province': 'Tiền Giang', 'province_normalized': 'Tiền Giang', 'district_normalized': 'Tân Phước', 'ward_normalized': ''}
# Actual   : {'province': 'An Giang', 'district': 'An Phú', 'ward': '', 'province_normalized': 'An Giang', 'district_normalized': 'An Phú', 'ward_normalized': ''}
# Correct  : 1/3
# Time     : 0.001471s
# ------------------------------
# --- Trường hợp #405 ---
# Input    : 'X An Đức, Huyên Ninh Giang, T.Hải Dương'
# Expected : {'district': 'Ninh Giang', 'ward': 'An Đức', 'province': 'Hải Dương', 'province_normalized': 'Hải Dương', 'district_normalized': 'Ninh Giang', 'ward_normalized': 'An Đức'}
# Actual   : {'province': 'Hải Dương', 'district': 'Ninh Giang', 'ward': 'Ân Đức', 'province_normalized': 'Hải Dương', 'district_normalized': 'Ninh Giang', 'ward_normalized': 'Ân Đức'}
# Correct  : 2/3
# Time     : 0.000576s
# ------------------------------
# --- Trường hợp #406 ---
# Input    : 'XTrung Kiên,,Tỉnh Vĩnh Phuúc'
# Expected : {'district': '', 'ward': 'Trung Kiên', 'province': 'Vĩnh Phúc', 'province_normalized': 'Vĩnh Phúc', 'district_normalized': '', 'ward_normalized': 'Trung Kiên'}
# Actual   : {'province': 'Trà Vinh', 'district': '', 'ward': '', 'province_normalized': 'Trà Vinh', 'district_normalized': '', 'ward_normalized': ''}
# Correct  : 1/3
# Time     : 0.001559s
# ------------------------------
# --- Trường hợp #407 ---
# Input    : 'X. Đông Lâm2, Huyen Tiền Hải, T.Thái Bình'
# Expected : {'district': 'Tiền Hải', 'ward': 'Đông Lâm', 'province': 'Thái Bình', 'province_normalized': 'Thái Bình', 'district_normalized': 'Tiền Hải', 'ward_normalized': 'Đông Lâm'}
# Actual   : {'province': 'Thái Bình', 'district': 'Tiền Hải', 'ward': 'Đồng Lâm', 'province_normalized': 'Thái Bình', 'district_normalized': 'Tiền Hải', 'ward_normalized': 'Đồng Lâm'}
# Correct  : 2/3
# Time     : 0.000544s
# ------------------------------
# --- Trường hợp #409 ---
# Input    : ' Đức Lĩnh,Vũ Quang,'
# Expected : {'district': 'Vũ Quang', 'ward': 'Đức Lĩnh', 'province': '', 'province_normalized': '', 'district_normalized': 'Vũ Quang', 'ward_normalized': 'Đức Lĩnh'}
# Actual   : {'province': 'Quảng Bình', 'district': '', 'ward': '', 'province_normalized': 'Quảng Bình', 'district_normalized': '', 'ward_normalized': ''}
# Correct  : 0/3
# Time     : 0.001297s
# ------------------------------
# --- Trường hợp #411 ---
# Input    : ' Yn phú, HBắc Mê, TỉnhV Hà giang'
# Expected : {'district': 'Bắc Mê', 'ward': 'Yên Phú', 'province': 'Hà Giang', 'province_normalized': 'Hà Giang', 'district_normalized': 'Bắc Mê', 'ward_normalized': 'Yên Phú'}
# Actual   : {'province': 'Hà Giang', 'district': 'Bắc Mê', 'ward': 'Yên Phụ', 'province_normalized': 'Hà Giang', 'district_normalized': 'Bắc Mê', 'ward_normalized': 'Yên Phụ'}
# Correct  : 2/3
# Time     : 0.000521s
# ------------------------------
# --- Trường hợp #412 ---
# Input    : 'Xuân Tân t.P Long Khánh '
# Expected : {'district': 'Long Khánh', 'ward': 'Xuân Tân', 'province': '', 'province_normalized': '', 'district_normalized': 'Long Khánh', 'ward_normalized': 'Xuân Tân'}
# Actual   : {'province': 'Đồng Nai', 'district': 'Long Khánh', 'ward': '', 'province_normalized': 'Đồng Nai', 'district_normalized': 'Long Khánh', 'ward_normalized': ''}
# Correct  : 1/3
# Time     : 0.001763s
# ------------------------------
# --- Trường hợp #417 ---
# Input    : 'Phú Đô HuyệnPhú Lươnz '
# Expected : {'district': 'Phú Lương', 'ward': 'Phú Đô', 'province': '', 'province_normalized': '', 'district_normalized': 'Phú Lương', 'ward_normalized': 'Phú Đô'}
# Actual   : {'province': 'Phú Thọ', 'district': '', 'ward': '', 'province_normalized': 'Phú Thọ', 'district_normalized': '', 'ward_normalized': ''}
# Correct  : 0/3
# Time     : 0.000946s
# ------------------------------
# --- Trường hợp #419 ---
# Input    : 'X.Phước Hiệp  Tỉnh Bến Tre'
# Expected : {'district': '', 'ward': 'Phước Hiệp', 'province': 'Bến Tre', 'province_normalized': 'Bến Tre', 'district_normalized': '', 'ward_normalized': 'Phước Hiệp'}
# Actual   : {'province': 'Bến Tre', 'district': 'Bến Tre', 'ward': '', 'province_normalized': 'Bến Tre', 'district_normalized': 'Bến Tre', 'ward_normalized': ''}
# Correct  : 1/3
# Time     : 0.000948s
# ------------------------------
# --- Trường hợp #420 ---
# Input    : 'XHuy Hạ,  phù Yêu, T.Sơn La'
# Expected : {'district': 'Phù Yên', 'ward': 'Huy Hạ', 'province': 'Sơn La', 'province_normalized': 'Sơn La', 'district_normalized': 'Phù Yên', 'ward_normalized': 'Huy Hạ'}
# Actual   : {'province': 'Sơn La', 'district': 'Sơn La', 'ward': '', 'province_normalized': 'Sơn La', 'district_normalized': 'Sơn La', 'ward_normalized': ''}
# Correct  : 1/3
# Time     : 0.000938s
# ------------------------------
# --- Trường hợp #422 ---
# Input    : ', Nam Đông,T. T.T.H'
# Expected : {'district': 'Nam Đông', 'ward': '', 'province': 'Thừa Thiên Huế', 'province_normalized': 'Thừa Thiên Huế', 'district_normalized': 'Nam Đông', 'ward_normalized': ''}
# Actual   : {'province': 'Hà Nam', 'district': '', 'ward': '', 'province_normalized': 'Hà Nam', 'district_normalized': '', 'ward_normalized': ''}
# Correct  : 1/3
# Time     : 0.000906s
# ------------------------------
# --- Trường hợp #427 ---
# Input    : 'X. Hương Liên HuyệnHương Khê T Hà Tinh'
# Expected : {'district': 'Hương Khê', 'ward': 'Hương Liên', 'province': 'Hà Tĩnh', 'province_normalized': 'Hà Tĩnh', 'district_normalized': 'Hương Khê', 'ward_normalized': 'Hương Liên'}
# Actual   : {'province': 'Hà Tĩnh', 'district': 'Hương Khê', 'ward': '', 'province_normalized': 'Hà Tĩnh', 'district_normalized': 'Hương Khê', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.001109s
# ------------------------------
# --- Trường hợp #429 ---
# Input    : 'Phườni Tràng Minh Q. Kiến An Thành phố Hải Phòng'
# Expected : {'district': 'Kiến An', 'ward': 'Tràng Minh', 'province': 'Hải Phòng', 'province_normalized': 'Hải Phòng', 'district_normalized': 'Kiến An', 'ward_normalized': 'Tràng Minh'}
# Actual   : {'province': 'Hải Phòng', 'district': 'Kiến An', 'ward': '', 'province_normalized': 'Hải Phòng', 'district_normalized': 'Kiến An', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.000389s
# ------------------------------
# --- Trường hợp #433 ---
# Input    : 'X. Thanh Phongjc , Tỉnhthanh hóa'
# Expected : {'district': '', 'ward': 'Thanh Phong', 'province': 'Thanh Hóa', 'province_normalized': 'Thanh Hóa', 'district_normalized': '', 'ward_normalized': 'Thanh Phong'}
# Actual   : {'province': 'Thanh Hóa', 'district': '', 'ward': '', 'province_normalized': 'Thanh Hóa', 'district_normalized': '', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.001089s
# ------------------------------
# --- Trường hợp #435 ---
# Input    : 'xã Bình Trung,,TLạng Son'
# Expected : {'district': '', 'ward': 'Bình Trung', 'province': 'Lạng Sơn', 'province_normalized': 'Lạng Sơn', 'district_normalized': '', 'ward_normalized': 'Bình Trung'}
# Actual   : {'province': 'Lạng Sơn', 'district': 'Lạng Sơn', 'ward': '', 'province_normalized': 'Lạng Sơn', 'district_normalized': 'Lạng Sơn', 'ward_normalized': ''}
# Correct  : 1/3
# Time     : 0.000894s
# ------------------------------
# --- Trường hợp #439 ---
# Input    : 'Đông thanh AnE Minh T kien Giang'
# Expected : {'district': 'An Minh', 'ward': 'Đông Thạnh', 'province': 'Kiên Giang', 'province_normalized': 'Kiên Giang', 'district_normalized': 'An Minh', 'ward_normalized': 'Đông Thạnh'}
# Actual   : {'province': 'Kiên Giang', 'district': '', 'ward': '', 'province_normalized': 'Kiên Giang', 'district_normalized': '', 'ward_normalized': ''}
# Correct  : 1/3
# Time     : 0.001019s
# ------------------------------
# --- Trường hợp #440 ---
# Input    : 'Xã Tân Lĩnh, H.Lục Yên, TYên Bái'
# Expected : {'district': 'Lục Yên', 'ward': 'Tân Lĩnh', 'province': 'Yên Bái', 'province_normalized': 'Yên Bái', 'district_normalized': 'Lục Yên', 'ward_normalized': 'Tân Lĩnh'}
# Actual   : {'province': 'Yên Bái', 'district': 'Lục Yên', 'ward': 'Tản Lĩnh', 'province_normalized': 'Yên Bái', 'district_normalized': 'Lục Yên', 'ward_normalized': 'Tản Lĩnh'}
# Correct  : 2/3
# Time     : 0.000348s
# ------------------------------
# --- Trường hợp #441 ---
# Input    : 'P Thủy Châu,T.X. hươngThủy,Thừa.t.Huế'
# Expected : {'district': 'Hương Thủy', 'ward': 'Thủy Châu', 'province': 'Thừa Thiên Huế', 'province_normalized': 'Thừa Thiên Huế', 'district_normalized': 'Hương Thủy', 'ward_normalized': 'Thủy Châu'}
# Actual   : {'province': 'Đà Nẵng', 'district': '', 'ward': '', 'province_normalized': 'Đà Nẵng', 'district_normalized': '', 'ward_normalized': ''}
# Correct  : 0/3
# Time     : 0.001033s
# ------------------------------
# --- Trường hợp #442 ---
# Input    : 'Thi trấ Ea. Knốp,H. Ea Kar,'
# Expected : {'district': 'Ea Kar', 'ward': 'Ea Knốp', 'province': '', 'province_normalized': '', 'district_normalized': 'Ea Kar', 'ward_normalized': 'Ea Knốp'}
# Actual   : {'province': 'Trà Vinh', 'district': '', 'ward': '', 'province_normalized': 'Trà Vinh', 'district_normalized': '', 'ward_normalized': ''}
# Correct  : 0/3
# Time     : 0.000981s
# ------------------------------
# --- Trường hợp #444 ---
# Input    : 'X.Nga Thanh hyện Nga son TỉnhThanhQ Hóa'
# Expected : {'district': 'Nga Sơn', 'ward': 'Nga Thanh', 'province': 'Thanh Hóa', 'province_normalized': 'Thanh Hóa', 'district_normalized': 'Nga Sơn', 'ward_normalized': 'Nga Thanh'}
# Actual   : {'province': 'Thanh Hóa', 'district': 'Nga Sơn', 'ward': '', 'province_normalized': 'Thanh Hóa', 'district_normalized': 'Nga Sơn', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.001240s
# ------------------------------
# --- Trường hợp #447 ---
# Input    : 'F Tân bình  dĩ An '
# Expected : {'district': 'Dĩ An', 'ward': 'Tân Bình', 'province': '', 'province_normalized': '', 'district_normalized': 'Dĩ An', 'ward_normalized': 'Tân Bình'}
# Actual   : {'province': 'Bình Dương', 'district': 'Dĩ An', 'ward': 'Tân Bình', 'province_normalized': 'Bình Dương', 'district_normalized': 'Dĩ An', 'ward_normalized': 'Tân Bình'}
# Correct  : 2/3
# Time     : 0.000258s
# ------------------------------
# --- Trường hợp #448 ---
# Input    : 'x2Trung Sơn,,TỉnhNghê An'
# Expected : {'district': '', 'ward': 'Trung Sơn', 'province': 'Nghệ An', 'province_normalized': 'Nghệ An', 'district_normalized': '', 'ward_normalized': 'Trung Sơn'}
# Actual   : {'province': 'Nghệ An', 'district': '', 'ward': '', 'province_normalized': 'Nghệ An', 'district_normalized': '', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.000864s
# ------------------------------
# --- Trường hợp #450 ---
# Input    : 'Tân Hòa,H. Phú Tân,TnhAn Giang'
# Expected : {'district': 'Phú Tân', 'ward': 'Tân Hòa', 'province': 'An Giang', 'province_normalized': 'An Giang', 'district_normalized': 'Phú Tân', 'ward_normalized': 'tân hòa'}
# Actual   : {'province': 'An Giang', 'district': 'Phú Tân', 'ward': 'Tân Hóa', 'province_normalized': 'An Giang', 'district_normalized': 'Phú Tân', 'ward_normalized': 'Tân Hóa'}
# Correct  : 2/3
# Time     : 0.000338s
# ------------------------------
# --- TỔNG KẾT ---
# TEAM_NAME = 'HK251'
# EXCEL_FILE = 'HK251.xlsx'
#    correct  total  score / 10  max_time_sec  avg_time_sec
# 0      917   1350        6.79        0.0028        0.0007
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.3/175.3 kB 4.4 MB/s eta 0:00:00
#
# Đã xuất kết quả chi tiết ra file HK251.xlsx
