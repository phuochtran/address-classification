# %% [markdown]
# # Data

# %%
# NOTE: you CAN change this cell
# If you want to use your own database, download it here
# !gdown ...
# !gdown --fuzzy https://drive.google.com/file/d/168XttTc8_UlYXuPHHkCKUh2bp_h3L9o8/view?usp=sharing -O list_address.json
# !gdown --fuzzy https://drive.google.com/file/d/176heW3Yco-kyXJl25byYDchTFa5Yso9x/view?usp=sharing -O abbreviations.json
# !gdown --fuzzy https://drive.google.com/file/d/1UFvugSSmVgruhK27CgcJy6kJtZNVG1Mw/view?usp=sharing -O list_district.txt
# !gdown --fuzzy https://drive.google.com/file/d/1dLQOYTQ4fRTTnd-OMc7W70oRw31KtvBo/view?usp=sharing -O list_province.txt
# !gdown --fuzzy https://drive.google.com/file/d/1Ex7v0TgE18xTF2z_wfhDrLPw6BPqHtZG/view?usp=sharing -O list_ward.txt
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=168XttTc8_UlYXuPHHkCKUh2bp_h3L9o8
# To: /content/list_address.json
# 100% 256k/256k [00:00<00:00, 79.6MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=176heW3Yco-kyXJl25byYDchTFa5Yso9x
# To: /content/abbreviations.json
# 100% 118/118 [00:00<00:00, 418kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1UFvugSSmVgruhK27CgcJy6kJtZNVG1Mw
# To: /content/list_district.txt
# 100% 4.80k/4.80k [00:00<00:00, 16.3MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1dLQOYTQ4fRTTnd-OMc7W70oRw31KtvBo
# To: /content/list_province.txt
# 100% 638/638 [00:00<00:00, 2.24MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1Ex7v0TgE18xTF2z_wfhDrLPw6BPqHtZG
# To: /content/list_ward.txt
# 100% 76.2k/76.2k [00:00<00:00, 72.2MB/s]

# %%
# NOTE: you CAN change this cell
# Add more to your needs
# you must place ALL pip install here
#!pip install editdistance
# !pip install gdown
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.12/dist-packages (5.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from gdown) (4.13.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from gdown) (3.19.1)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.12/dist-packages (from gdown) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from gdown) (4.67.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (2025.8.3)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (1.7.1)

# %%
# NOTE: you CAN change this cell
# import your library here
import time
import re
import json
from functools import lru_cache

# %% [markdown]
# # Algorithm

# %%
# NOTE: you MUST change this cell
# New methods / functions must be written under class Solution.

THRESHOLD = 0.83
MAX_DISTANCE = 3
_WARD_FALLBACK_TIME_LIMIT_SEC = 0.03
_MAPPING = [
    # oa: o + (a có dấu) -> (o có dấu) + a
    ("oà", "òa"), ("oá", "óa"), ("oả", "ỏa"), ("oã", "õa"), ("oạ", "ọa"),
    ("Oà", "Òa"), ("Oá", "Óa"), ("Oả", "Ỏa"), ("Oã", "Õa"), ("Oạ", "Ọa"),
    ("oÀ", "òa"), ("oÁ", "óa"), ("oẢ", "ỏa"), ("oÃ", "õa"), ("oẠ", "ọa"),
    ("OÀ", "ÒA"), ("OÁ", "ÓA"), ("OẢ", "ỎA"), ("OÃ", "ÕA"), ("OẠ", "ỌA"),

    # oe: o + (e có dấu) -> (o có dấu) + e
    ("oè", "òe"), ("oé", "óe"), ("oẻ", "ỏe"), ("oẽ", "õe"), ("oẹ", "ọe"),
    ("Oè", "Òe"), ("Oé", "Óe"), ("Oẻ", "Ỏe"), ("Oẽ", "Õe"), ("Oẹ", "Ọe"),
    ("oÈ", "òe"), ("oÉ", "óe"), ("oẺ", "ỏe"), ("oẼ", "õe"), ("oẸ", "ọe"),
    ("OÈ", "ÒE"), ("OÉ", "ÓE"), ("OẺ", "ỎE"), ("OẼ", "ÕE"), ("OẸ", "ỌE"),

    # uy: u + (y có dấu) -> (u có dấu) + y
    ("uỳ", "ùy"), ("uý", "úy"), ("uỷ", "ủy"), ("uỹ", "ũy"), ("uỵ", "ụy"),
    ("Uỳ", "Ùy"), ("Uý", "Úy"), ("Uỷ", "Ủy"), ("Uỹ", "Ũy"), ("Uỵ", "Ụy"),
    ("uỲ", "ùy"), ("uÝ", "úy"), ("uỶ", "ủy"), ("uỸ", "ũy"), ("uỴ", "ụy"),
    ("UỲ", "ÙY"), ("UÝ", "ÚY"), ("UỶ", "ỦY"), ("UỸ", "ŨY"), ("UỴ", "ỤY"),
]
_REMOVE_DATA_BY_TEAMPLTE_FILE = False
class Solution:
    def __init__(self):
        self.province_path = 'list_province.txt'
        self.district_path = 'list_district.txt'
        self.ward_path = 'list_ward.txt'

        # address data
        self.address_path = 'list_address.json'
        self.abbreviate_path = 'abbreviations.json'
        self.province_data = self.TrieNode()
        self.district_data = {}
        self.ward_data = {}
        self.all_districts_data = self.TrieNode()
        self.province_wards_data = {}

        # Load data
        self.load_hierarchical_data()

    class TrieNode():
        def __init__(self):
            self.childs = {}
            self.exact_word = None
            self.key_word = None

    def remove_prefixes(self, text, level):
        text = text.strip().lower()

        if level == 'province':
            text = re.sub(r'\b(tỉnh|tp|tnh|tỉnhc|tỉnhv|tpho|thanhpho|thànhphô|thànhphố|thphố|tphố|thpho|tp\.)\s*', '', text)
        elif level == 'district':
            text = re.sub(r'\b(huyện|hyen|huyen|quận|quan|qận|qan|qun|tp|tpho|thanhpho|thànhphô|thànhphố|thphố|tphố|thpho|q\.)\s*', '', text)
        elif level == 'ward':
            text = re.sub(r'\b(xã|thịxã|thxã|phường|phưòng|phung|tt|tx|p|Thi trấ|F\.)\s*', '', text)

        return text

    def insert(self, root_node, key, word, level):
        # Remove prefixes
        cleaned_key = self.remove_prefixes(key, level)
        cleaned_key = cleaned_key.replace(" ", "").strip().lower()

        node = root_node
        for char in cleaned_key:
            if char not in node.childs:
                node.childs[char] = self.TrieNode()
            node = node.childs[char]
        node.exact_word = word.strip()
        node.key_word = cleaned_key

    def load_hierarchical_data(self):
        """Load data from the hierarchical JSON file"""
        def remove_prefix(name):
            if not name:
                return ""
            name = re.sub(r'^(tỉnh|thành phố|huyện|quận|thị xã|xã|phường|thị trấn)\s+', '', name, flags=re.IGNORECASE)
            return name.strip()

        with open(self.province_path, 'r', encoding='utf-8') as f:
            flat_provinces = [line.strip() for line in f if line.strip()]

        with open(self.district_path, 'r', encoding='utf-8') as f:
            flat_districts = [line.strip() for line in f if line.strip()]

        with open(self.ward_path, 'r', encoding='utf-8') as f:
            flat_wards = [line.strip() for line in f if line.strip()]

        with open(self.address_path, "r", encoding='utf-8') as file:
            data = json.load(file)

        try:
            with open(self.abbreviate_path, 'r', encoding='utf-8') as f:
                self.abbreviations = json.load(f)
        except FileNotFoundError:
            self.abbreviations = {"province": {}, "district": {}, "ward": {}}

        # Load provinces
        for province_name in data.keys():
            province_name = remove_prefix(province_name)
            if _REMOVE_DATA_BY_TEAMPLTE_FILE and province_name not in flat_provinces:
                continue
            self.insert(self.province_data, province_name, province_name, 'province')
            for abbreviation in self.abbreviations.get("province", {}).get(province_name, []):
                self.insert(self.province_data, abbreviation, province_name, 'province')

        # Load districts and wards
        for province_name, districts in data.items():
            province_name = remove_prefix(province_name)
            if _REMOVE_DATA_BY_TEAMPLTE_FILE and province_name not in flat_provinces:
                continue
            # Create a trie for districts in province
            self.district_data[province_name] = self.TrieNode()

            # Create a trie for wards in this province (skip district level)
            self.province_wards_data[province_name] = self.TrieNode()

            for district_name, wards in districts.items():
                district_name = remove_prefix(district_name)
                if _REMOVE_DATA_BY_TEAMPLTE_FILE and district_name not in flat_districts:
                    continue
                # Insert district into province's district trie
                self.insert(self.district_data[province_name], district_name, district_name, 'district')
                # Insert district into all districts trie (for skip province)
                self.insert(self.all_districts_data, district_name, district_name, 'district')

                for abbreviation in self.abbreviations.get("district", {}).get(district_name, []):
                    self.insert(self.province_data, abbreviation, district_name, 'district')

                # Create a trie for wards in this district
                ward_key = (province_name, district_name)
                self.ward_data[ward_key] = self.TrieNode()

                # Insert wards into district's ward trie
                for ward_name in wards:
                    ward_name = remove_prefix(ward_name)
                    if _REMOVE_DATA_BY_TEAMPLTE_FILE and ward_name not in flat_wards:
                        continue
                    self.insert(self.ward_data[ward_key], ward_name, ward_name, 'ward')
                    # Insert ward into province's ward trie (skip district level)
                    self.insert(self.province_wards_data[province_name], ward_name, ward_name, 'ward')

                    for abbreviation in self.abbreviations.get("ward", {}).get(ward_name, []):
                        self.insert(self.province_data, abbreviation, ward_name, 'ward')

    def find_closest_string(self, root_node, word, level, deadline=None):
        # Remove prefixes from search word
        word = self.remove_prefixes(word, level).strip().lower()

        results = []
        max_distance = MAX_DISTANCE
        initial_row = list(range(len(word) + 1))

        def search_recursive(node, prefix, previous_row):
            nonlocal max_distance

            # early stop when timeout
            if deadline is not None and time.perf_counter() > deadline:
                return

            current_word = prefix

            if node.key_word and previous_row[-1] <= max_distance:
                results.append((node.key_word, node.exact_word, previous_row[-1]))
                max_distance = previous_row[-1]

            for char, child_node in node.childs.items():
                current_row = [previous_row[0] + 1]

                for i in range(1, len(word) + 1):
                    insert_cost = current_row[i - 1] + 1
                    delete_cost = previous_row[i] + 1
                    replace_cost = previous_row[i - 1] + (0 if word[i - 1] == char else 1)
                    current_row.append(min(insert_cost, delete_cost, replace_cost))

                if min(current_row) <= max_distance:
                    search_recursive(child_node, current_word + char, current_row)

        search_recursive(root_node, "", initial_row)
        results.sort(key=lambda x: x[2])

        dynamic_threshold = THRESHOLD - (len(word) / 100)
        if results:
            return results[0][1] if dynamic_threshold <= 1 - (results[0][2]/max(len(word), len(results[0][0]))) else ""
        return ""

    def normalize_vn_legacy_to_modern(self, text: str) -> str:
        if not text:
            return text
        for old, new in _MAPPING:
            text = text.replace(old, new)
        return text

    def sanitize_string(self, input_word):
        input_word = input_word.strip().lower()
        input_word = self.normalize_vn_legacy_to_modern(input_word)
        input_word = re.sub(r'[\s,.~-]', ' ', input_word)
        return input_word.strip()

    def slide_and_combine_with_indices(self, words):
        n = len(words)
        results = []

        for i in range(n - 1, -1, -1):
            window = words[max(0, i - 2):i + 1]

            if len(window) == 3:
                w1, w2, w3 = window
                results.extend([(f"{w2}{w3}", i - 1), (f"{w1}{w2}", i - 2), (w3, i), (f"{w1}{w2}{w3}", i - 2)])
            elif len(window) == 2:
                w1, w2 = window
                results.extend([(f"{w1}{w2}", i - 1), (w2, i)])
            elif len(window) == 1:
                results.append((window[0], i))

        return results

    def process(self, s: str):
        # write your process string here
        result = {
            "province": "",
            "district": "",
            "ward": ""
        }

        start_time = time.perf_counter()
        cleaned_input = self.sanitize_string(s).split()

        # Step 1: Find province
        province_candidates = self.slide_and_combine_with_indices(cleaned_input)
        matched_start_index = -1
        processed_province_candidates = set()

        for i, (candidate, start_index) in enumerate(province_candidates):
            if candidate in processed_province_candidates:
                continue
            processed_province_candidates.add(candidate)

            result["province"] = self.find_closest_string(self.province_data, candidate, 'province')
            if result["province"]:
                matched_start_index = start_index
                cleaned_input = cleaned_input[:matched_start_index]
                break

        # Step 2: Find district
        district_found = False
        if result["province"] and result["province"] in self.district_data:
            district_candidates = self.slide_and_combine_with_indices(cleaned_input)
            matched_start_index = -1
            processed_district_candidates = set()

            for i, (candidate, start_index) in enumerate(district_candidates):
                if candidate in processed_district_candidates:
                    continue
                processed_district_candidates.add(candidate)

                result["district"] = self.find_closest_string(
                    self.district_data[result["province"]],
                    candidate,
                    'district'
                )
                if result["district"]:
                    matched_start_index = start_index
                    cleaned_input = cleaned_input[:matched_start_index]
                    district_found = True
                    break

        if not result["province"]:
            district_candidates = self.slide_and_combine_with_indices(cleaned_input)
            matched_start_index = -1
            processed_district_candidates = set()
            deadline = time.perf_counter() + _WARD_FALLBACK_TIME_LIMIT_SEC

            for i, (candidate, start_index) in enumerate(district_candidates):
                if time.perf_counter() > deadline:
                    break
                if candidate in processed_district_candidates:
                    continue
                processed_district_candidates.add(candidate)

                result["district"] = self.find_closest_string(
                    self.all_districts_data,
                    candidate,
                    'district',
                    deadline=deadline
                )
                if result["district"]:
                    matched_start_index = start_index
                    cleaned_input = cleaned_input[:matched_start_index]
                    district_found = True
                    break

        # Step 3: Find ward
        if result["province"] and result["district"]:
            ward_key = (result["province"], result["district"])
            if ward_key in self.ward_data:
                ward_candidates = self.slide_and_combine_with_indices(cleaned_input)
                processed_ward_candidates = set()

                for i, (candidate, start_index) in enumerate(ward_candidates):
                    if candidate in processed_ward_candidates:
                        continue
                    processed_ward_candidates.add(candidate)

                    result["ward"] = self.find_closest_string(
                        self.ward_data[ward_key],
                        candidate,
                        'ward'
                    )
                    if result["ward"]:
                        break

        elif result["province"] and not result["district"]:
            if result["province"] in self.province_wards_data:
                ward_candidates = self.slide_and_combine_with_indices(cleaned_input)
                processed_ward_candidates = set()
                deadline = time.perf_counter() + _WARD_FALLBACK_TIME_LIMIT_SEC

                for i, (candidate, start_index) in enumerate(ward_candidates):
                    if time.perf_counter() > deadline:
                        break
                    if candidate in processed_ward_candidates:
                        continue
                    processed_ward_candidates.add(candidate)

                    result["ward"] = self.find_closest_string(
                        self.province_wards_data[result["province"]],
                        candidate,
                        'ward',
                        deadline=deadline
                    )
                    if result["ward"]:
                        break

        return result

# %% [markdown]
# # Run

# %%
# NOTE: DO NOT change this cell
# !rm -rf test.json
# this link is public test
# !gdown --fuzzy https://drive.google.com/file/d/1PBt3U9I3EH885CDhcXspebyKI5Vw6uLB/view?usp=sharing -O test.json
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1PBt3U9I3EH885CDhcXspebyKI5Vw6uLB
# To: /content/test.json
# 100% 79.4k/79.4k [00:00<00:00, 58.4MB/s]

# %%
# CORRECT TESTS
groups_province = {}
groups_district = {'hòa bình': ['Hoà Bình', 'Hòa Bình'], 'kbang': ['Kbang', 'KBang'], 'quy nhơn': ['Qui Nhơn', 'Quy Nhơn']}
groups_ward = {'ái nghĩa': ['ái Nghĩa', 'Ái Nghĩa'], 'ái quốc': ['ái Quốc', 'Ái Quốc'], 'ái thượng': ['ái Thượng', 'Ái Thượng'], 'ái tử': ['ái Tử', 'Ái Tử'], 'ấm hạ': ['ấm Hạ', 'Ấm Hạ'], 'an ấp': ['An ấp', 'An Ấp'], 'ẳng cang': ['ẳng Cang', 'Ẳng Cang'], 'ẳng nưa': ['ẳng Nưa', 'Ẳng Nưa'], 'ẳng tở': ['ẳng Tở', 'Ẳng Tở'], 'an hòa': ['An Hoà', 'An Hòa'], 'ayun': ['Ayun', 'AYun'], 'bắc ái': ['Bắc ái', 'Bắc Ái'], 'bảo ái': ['Bảo ái', 'Bảo Ái'], 'bình hòa': ['Bình Hoà', 'Bình Hòa'], 'châu ổ': ['Châu ổ', 'Châu Ổ'], 'chư á': ['Chư á', 'Chư Á'], 'chư rcăm': ['Chư Rcăm', 'Chư RCăm'], 'cộng hòa': ['Cộng Hoà', 'Cộng Hòa'], 'cò nòi': ['Cò  Nòi', 'Cò Nòi'], 'đại ân 2': ['Đại Ân  2', 'Đại Ân 2'], 'đak ơ': ['Đak ơ', 'Đak Ơ'], "đạ m'ri": ["Đạ M'ri", "Đạ M'Ri"], 'đông hòa': ['Đông Hoà', 'Đông Hòa'], 'đồng ích': ['Đồng ích', 'Đồng Ích'], 'hải châu i': ['Hải Châu  I', 'Hải Châu I'], 'hải hòa': ['Hải Hoà', 'Hải Hòa'], 'hành tín đông': ['Hành Tín  Đông', 'Hành Tín Đông'], 'hiệp hòa': ['Hiệp Hoà', 'Hiệp Hòa'], 'hòa bắc': ['Hoà Bắc', 'Hòa Bắc'], 'hòa bình': ['Hoà Bình', 'Hòa Bình'], 'hòa châu': ['Hoà Châu', 'Hòa Châu'], 'hòa hải': ['Hoà Hải', 'Hòa Hải'], 'hòa hiệp trung': ['Hoà Hiệp Trung', 'Hòa Hiệp Trung'], 'hòa liên': ['Hoà Liên', 'Hòa Liên'], 'hòa lộc': ['Hoà Lộc', 'Hòa Lộc'], 'hòa lợi': ['Hoà Lợi', 'Hòa Lợi'], 'hòa long': ['Hoà Long', 'Hòa Long'], 'hòa mạc': ['Hoà Mạc', 'Hòa Mạc'], 'hòa minh': ['Hoà Minh', 'Hòa Minh'], 'hòa mỹ': ['Hoà Mỹ', 'Hòa Mỹ'], 'hòa phát': ['Hoà Phát', 'Hòa Phát'], 'hòa phong': ['Hoà Phong', 'Hòa Phong'], 'hòa phú': ['Hoà Phú', 'Hòa Phú'], 'hòa phước': ['Hoà Phước', 'Hòa Phước'], 'hòa sơn': ['Hoà Sơn', 'Hòa Sơn'], 'hòa tân': ['Hoà Tân', 'Hòa Tân'], 'hòa thuận': ['Hoà Thuận', 'Hòa Thuận'], 'hòa tiến': ['Hoà Tiến', 'Hòa Tiến'], 'hòa trạch': ['Hoà Trạch', 'Hòa Trạch'], 'hòa vinh': ['Hoà Vinh', 'Hòa Vinh'], 'hương hòa': ['Hương Hoà', 'Hương Hòa'], 'ích hậu': ['ích Hậu', 'Ích Hậu'], 'ít ong': ['ít Ong', 'Ít Ong'], 'khánh hòa': ['Khánh Hoà', 'Khánh Hòa'], 'krông á': ['Krông Á', 'KRông á'], 'lộc hòa': ['Lộc Hoà', 'Lộc Hòa'], 'minh hòa': ['Minh Hoà', 'Minh Hòa'], 'mường ải': ['Mường ải', 'Mường Ải'], 'mường ẳng': ['Mường ẳng', 'Mường Ẳng'], 'nậm ét': ['Nậm ét', 'Nậm Ét'], 'nam hòa': ['Nam Hoà', 'Nam Hòa'], 'na ư': ['Na ư', 'Na Ư'], 'ngã sáu': ['Ngã sáu', 'Ngã Sáu'], 'nghi hòa': ['Nghi Hoà', 'Nghi Hòa'], 'nguyễn úy': ['Nguyễn Uý', 'Nguyễn úy', 'Nguyễn Úy'], 'nhân hòa': ['Nhân Hoà', 'Nhân Hòa'], 'nhơn hòa': ['Nhơn Hoà', 'Nhơn Hòa'], 'nhơn nghĩa a': ['Nhơn nghĩa A', 'Nhơn Nghĩa A'], 'phúc ứng': ['Phúc ứng', 'Phúc Ứng'], 'phước hòa': ['Phước Hoà', 'Phước Hòa'], 'sơn hóa': ['Sơn Hoá', 'Sơn Hóa'], 'tạ an khương đông': ['Tạ An Khương  Đông', 'Tạ An Khương Đông'], 'tạ an khương nam': ['Tạ An Khương  Nam', 'Tạ An Khương Nam'], 'tăng hòa': ['Tăng Hoà', 'Tăng Hòa'], 'tân hòa': ['Tân Hoà', 'Tân Hòa'], 'tân hòa thành': ['Tân Hòa  Thành', 'Tân Hòa Thành'], 'tân khánh trung': ['Tân  Khánh Trung', 'Tân Khánh Trung'], 'tân lợi': ['Tân lợi', 'Tân Lợi'], 'thái hòa': ['Thái Hoà', 'Thái Hòa'], 'thiết ống': ['Thiết ống', 'Thiết Ống'], 'thuận hòa': ['Thuận Hoà', 'Thuận Hòa'], 'thượng ấm': ['Thượng ấm', 'Thượng Ấm'], 'thụy hương': ['Thuỵ Hương', 'Thụy Hương'], 'thủy xuân': ['Thuỷ Xuân', 'Thủy Xuân'], 'tịnh ấn đông': ['Tịnh ấn Đông', 'Tịnh Ấn Đông'], 'tịnh ấn tây': ['Tịnh ấn Tây', 'Tịnh Ấn Tây'], 'triệu ái': ['Triệu ái', 'Triệu Ái'], 'triệu ẩu': ['Triệu ẩu', 'Triệu Ẩu'], 'trung hòa': ['Trung Hoà', 'Trung Hòa'], 'trung ý': ['Trung ý', 'Trung Ý'], 'tùng ảnh': ['Tùng ảnh', 'Tùng Ảnh'], 'úc kỳ': ['úc Kỳ', 'Úc Kỳ'], 'ứng hòe': ['ứng Hoè', 'Ứng Hoè'], 'vĩnh hòa': ['Vĩnh Hoà', 'Vĩnh Hòa'], 'vũ hòa': ['Vũ Hoà', 'Vũ Hòa'], 'xuân ái': ['Xuân ái', 'Xuân Ái'], 'xuân áng': ['Xuân áng', 'Xuân Áng'], 'xuân hòa': ['Xuân Hoà', 'Xuân Hòa'], 'xuất hóa': ['Xuất Hoá', 'Xuất Hóa'], 'ỷ la': ['ỷ La', 'Ỷ La']}
groups_ward.update({1: ['1', '01'], 2: ['2', '02'], 3: ['3', '03'], 4: ['4', '04'], 5: ['5', '05'], 6: ['6', '06'], 7: ['7', '07'], 8: ['8', '08'], 9: ['9', '09']})
def to_same(groups):
    same = {ele: k for k, v in groups.items() for ele in v}
    return same
same_province = to_same(groups_province)
same_district = to_same(groups_district)
same_ward = to_same(groups_ward)
def normalize(text, same_dict):
    return same_dict.get(text, text)

# %%
TEAM_NAME = 'HK251'
EXCEL_FILE = f'{TEAM_NAME}.xlsx'

import json
import time
with open('test.json') as f:
    data = json.load(f)

summary_only = False
df = []
solution = Solution()
timer = []
correct = 0
for test_idx, data_point in enumerate(data):
    address = data_point["text"]

    ok = 0
    try:
        answer = data_point["result"]
        answer["province_normalized"] = normalize(answer["province"], same_province)
        answer["district_normalized"] = normalize(answer["district"], same_district)
        answer["ward_normalized"] = normalize(answer["ward"], same_ward)

        start = time.perf_counter_ns()
        result = solution.process(address)
        finish = time.perf_counter_ns()
        timer.append(finish - start)
        result["province_normalized"] = normalize(result["province"], same_province)
        result["district_normalized"] = normalize(result["district"], same_district)
        result["ward_normalized"] = normalize(result["ward"], same_ward)

        province_correct = int(answer["province_normalized"] == result["province_normalized"])
        district_correct = int(answer["district_normalized"] == result["district_normalized"])
        ward_correct = int(answer["ward_normalized"] == result["ward_normalized"])
        ok = province_correct + district_correct + ward_correct

        #Print kqua
        if not summary_only and ok !=3:
            print(f"Case #{test_idx+1} ---")
            print(f"Input    : '{address}'")
            print(f"Expected : {answer}")
            print(f"Actual   : {result}")
            print(f"Correct  : {ok}/3")
            print(f"Time     : {timer[-1] / 1_000_000_000:.6f}s")
            print("-" * 30)

        df.append([
            test_idx,
            address,
            answer["province"],
            result["province"],
            answer["province_normalized"],
            result["province_normalized"],
            province_correct,
            answer["district"],
            result["district"],
            answer["district_normalized"],
            result["district_normalized"],
            district_correct,
            answer["ward"],
            result["ward"],
            answer["ward_normalized"],
            result["ward_normalized"],
            ward_correct,
            ok,
            timer[-1] / 1_000_000_000,
        ])
    except Exception as e:
        print(f"Case #{test_idx+1} with input: '{address}'")
        print(f"Exception: {e}")
        df.append([
            test_idx,
            address,
            answer.get("province", "N/A"), "EXCEPTION", answer.get("province_normalized", "N/A"), "EXCEPTION", 0,
            answer.get("district", "N/A"), "EXCEPTION", answer.get("district_normalized", "N/A"), "EXCEPTION", 0,
            answer.get("ward", "N/A"), "EXCEPTION", answer.get("ward_normalized", "N/A"), "EXCEPTION", 0,
            0, 0,
        ])
        pass
    correct += ok

print(f"Summary")
total = len(data) * 3
score_scale_10 = round(correct / total * 10, 2)
if len(timer) == 0:
    timer = [0]
max_time_sec = round(max(timer) / 1_000_000_000, 4)
avg_time_sec = round((sum(timer) / len(timer)) / 1_000_000_000, 4)

import pandas as pd

df2 = pd.DataFrame(
    [[correct, total, score_scale_10, max_time_sec, avg_time_sec]],
    columns=['correct', 'total', 'score / 10', 'max_time_sec', 'avg_time_sec',],
)


columns = [
    'ID', 'text',
    'province', 'province_student', 'province_normalized', 'province_student_normalized', 'province_correct',
    'district', 'district_student', 'district_normalized', 'district_student_normalized', 'district_correct',
    'ward', 'ward_student', 'ward_normalized', 'ward_student_normalized', 'ward_correct',
    'total_correct', 'time_sec',
]

df = pd.DataFrame(df)
df.columns = columns

print(f'{TEAM_NAME = }')
print(f'{EXCEL_FILE = }')
print(df2)

# !pip install -q xlsxwriter
writer = pd.ExcelWriter(EXCEL_FILE, engine='xlsxwriter')
df2.to_excel(writer, index=False, sheet_name='summary')
df.to_excel(writer, index=False, sheet_name='details')
writer.close()
# Out:
# Case #1 ---
# Input    : 'TT Tân Bình Huyện Yên Sơn, Tuyên Quang'
# Expected : {'province': 'Tuyên Quang', 'district': 'Yên Sơn', 'ward': 'Tân Bình', 'province_normalized': 'Tuyên Quang', 'district_normalized': 'Yên Sơn', 'ward_normalized': 'Tân Bình'}
# Actual   : {'province': 'Tuyên Quang', 'district': 'Yên Sơn', 'ward': '', 'province_normalized': 'Tuyên Quang', 'district_normalized': 'Yên Sơn', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.003079s
# ------------------------------
# Case #2 ---
# Input    : '357/28,Ng-T- Thuật,P1,Q3,TP.HồChíMinh.'
# Expected : {'province': 'Hồ Chí Minh', 'district': '', 'ward': '', 'province_normalized': 'Hồ Chí Minh', 'district_normalized': '', 'ward_normalized': ''}
# Actual   : {'province': 'Hồ Chí Minh', 'district': '', 'ward': '1', 'province_normalized': 'Hồ Chí Minh', 'district_normalized': '', 'ward_normalized': 1}
# Correct  : 2/3
# Time     : 0.006154s
# ------------------------------
# Case #3 ---
# Input    : '284DBis Ng Văn Giáo, P3, Mỹ Tho, T.Giang.'
# Expected : {'province': 'Tiền Giang', 'district': 'Mỹ Tho', 'ward': '3', 'province_normalized': 'Tiền Giang', 'district_normalized': 'Mỹ Tho', 'ward_normalized': 3}
# Actual   : {'province': '', 'district': 'Mỹ Tho', 'ward': '', 'province_normalized': '', 'district_normalized': 'Mỹ Tho', 'ward_normalized': ''}
# Correct  : 1/3
# Time     : 0.026253s
# ------------------------------
# Case #26 ---
# Input    : 'Số 259/54/8, Tổ 28, KP1, Long Bình Tân, Biên Hòa, Đồng Nai.'
# Expected : {'province': 'Đồng Nai', 'district': 'Biên Hòa', 'ward': 'Long Bình Tân', 'province_normalized': 'Đồng Nai', 'district_normalized': 'Biên Hòa', 'ward_normalized': 'Long Bình Tân'}
# Actual   : {'province': 'Đồng Nai', 'district': 'Biên Hòa', 'ward': 'Long Bình', 'province_normalized': 'Đồng Nai', 'district_normalized': 'Biên Hòa', 'ward_normalized': 'Long Bình'}
# Correct  : 2/3
# Time     : 0.001044s
# ------------------------------
# Case #29 ---
# Input    : 'Tiểu khu 3, thị trấn Ba Hàng, huyện Phổ Yên, tỉnh Thái Nguyên.'
# Expected : {'province': '', 'district': '', 'ward': '', 'province_normalized': '', 'district_normalized': '', 'ward_normalized': ''}
# Actual   : {'province': 'Thái Nguyên', 'district': 'Phổ Yên', 'ward': 'Ba Hàng', 'province_normalized': 'Thái Nguyên', 'district_normalized': 'Phổ Yên', 'ward_normalized': 'Ba Hàng'}
# Correct  : 0/3
# Time     : 0.001049s
# ------------------------------
# Case #35 ---
# Input    : 'Hoằng Anh Thành phố Thanh Hóa, Thanh Hóa'
# Expected : {'province': 'Thanh Hóa', 'district': 'Thanh Hóa', 'ward': 'Hoằng Anh', 'province_normalized': 'Thanh Hóa', 'district_normalized': 'Thanh Hóa', 'ward_normalized': 'Hoằng Anh'}
# Actual   : {'province': 'Thanh Hóa', 'district': 'Thanh Hóa', 'ward': 'Long Anh', 'province_normalized': 'Thanh Hóa', 'district_normalized': 'Thanh Hóa', 'ward_normalized': 'Long Anh'}
# Correct  : 2/3
# Time     : 0.001695s
# ------------------------------
# Case #44 ---
# Input    : '154/4/81 Nguyễn - Phúc Chu, P15, TB, TP. Hồ Chí Minh'
# Expected : {'province': '', 'district': '', 'ward': '', 'province_normalized': '', 'district_normalized': '', 'ward_normalized': ''}
# Actual   : {'province': 'Hồ Chí Minh', 'district': '', 'ward': '15', 'province_normalized': 'Hồ Chí Minh', 'district_normalized': '', 'ward_normalized': '15'}
# Correct  : 1/3
# Time     : 0.009906s
# ------------------------------
# Case #54 ---
# Input    : 'Thái Hòa Huyện Thái Thụy, Thái Bình'
# Expected : {'province': 'Thái Bình', 'district': 'Thái Thụy', 'ward': 'Thái Hòa', 'province_normalized': 'Thái Bình', 'district_normalized': 'Thái Thụy', 'ward_normalized': 'thái hòa'}
# Actual   : {'province': 'Thái Bình', 'district': 'Thái Thụy', 'ward': '', 'province_normalized': 'Thái Bình', 'district_normalized': 'Thái Thụy', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.001855s
# ------------------------------
# Case #76 ---
# Input    : '55/30 Nguyễn - Thượng Hiền,P5,BT, TP. Hồ Chí Minh'
# Expected : {'province': 'Hồ Chí Minh', 'district': 'Bình Thạnh', 'ward': '5', 'province_normalized': 'Hồ Chí Minh', 'district_normalized': 'Bình Thạnh', 'ward_normalized': 5}
# Actual   : {'province': 'Hồ Chí Minh', 'district': '', 'ward': '5', 'province_normalized': 'Hồ Chí Minh', 'district_normalized': '', 'ward_normalized': 5}
# Correct  : 2/3
# Time     : 0.011885s
# ------------------------------
# Case #86 ---
# Input    : 'Khu phố Nam Tân, TT Thuận Nam, Hàm Thuận Bắc, Bình Thuận.'
# Expected : {'province': '', 'district': '', 'ward': '', 'province_normalized': '', 'district_normalized': '', 'ward_normalized': ''}
# Actual   : {'province': 'Bình Thuận', 'district': 'Hàm Thuận Bắc', 'ward': '', 'province_normalized': 'Bình Thuận', 'district_normalized': 'Hàm Thuận Bắc', 'ward_normalized': ''}
# Correct  : 1/3
# Time     : 0.002975s
# ------------------------------
# Case #93 ---
# Input    : 'Hoằng Minh, Hoằng Hóa Thanh Hóa'
# Expected : {'province': 'Thanh Hóa', 'district': 'Hoằng Hóa', 'ward': 'Hoằng Minh', 'province_normalized': 'Thanh Hóa', 'district_normalized': 'Hoằng Hóa', 'ward_normalized': 'Hoằng Minh'}
# Actual   : {'province': 'Thanh Hóa', 'district': 'Hoằng Hóa', 'ward': 'Hoằng Trinh', 'province_normalized': 'Thanh Hóa', 'district_normalized': 'Hoằng Hóa', 'ward_normalized': 'Hoằng Trinh'}
# Correct  : 2/3
# Time     : 0.001031s
# ------------------------------
# Case #111 ---
# Input    : 'Số 7/Q3, KPI, Phường Long Bình Tân, Tp Biên Hoà, Đồng Nai.'
# Expected : {'province': 'Đồng Nai', 'district': 'Biên Hòa', 'ward': 'Long Bình Tân', 'province_normalized': 'Đồng Nai', 'district_normalized': 'Biên Hòa', 'ward_normalized': 'Long Bình Tân'}
# Actual   : {'province': 'Đồng Nai', 'district': 'Biên Hòa', 'ward': 'Long Bình', 'province_normalized': 'Đồng Nai', 'district_normalized': 'Biên Hòa', 'ward_normalized': 'Long Bình'}
# Correct  : 2/3
# Time     : 0.003483s
# ------------------------------
# Case #114 ---
# Input    : 'L10C12 Hẻm 90, Ng, Bỉnh Khiêm, TP. Rạch Giá, Kiên Giang'
# Expected : {'province': 'Kiên Giang', 'district': '', 'ward': '', 'province_normalized': 'Kiên Giang', 'district_normalized': '', 'ward_normalized': ''}
# Actual   : {'province': 'Kiên Giang', 'district': 'Rạch Giá', 'ward': '', 'province_normalized': 'Kiên Giang', 'district_normalized': 'Rạch Giá', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.007262s
# ------------------------------
# Case #123 ---
# Input    : '14.5 Block A2, The Mansion, ĐS 7,KDC 13E,Ấp 5,PP,BC, TP.HCM'
# Expected : {'province': 'Hồ Chí Minh', 'district': '', 'ward': '', 'province_normalized': 'Hồ Chí Minh', 'district_normalized': '', 'ward_normalized': ''}
# Actual   : {'province': 'Hồ Chí Minh', 'district': '5', 'ward': '7', 'province_normalized': 'Hồ Chí Minh', 'district_normalized': '5', 'ward_normalized': 7}
# Correct  : 1/3
# Time     : 0.001405s
# ------------------------------
# Case #140 ---
# Input    : 'F2B PhanVănTr P.5,GV,TP.Hồ Chí Minh'
# Expected : {'province': 'Hồ Chí Minh', 'district': '', 'ward': '', 'province_normalized': 'Hồ Chí Minh', 'district_normalized': '', 'ward_normalized': ''}
# Actual   : {'province': 'Hồ Chí Minh', 'district': '5', 'ward': '', 'province_normalized': 'Hồ Chí Minh', 'district_normalized': '5', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.002001s
# ------------------------------
# Case #155 ---
# Input    : 'Hải Ba  Hải Lăng '
# Expected : {'district': 'Hải Lăng', 'ward': 'Hải Ba', 'province': '', 'province_normalized': '', 'district_normalized': 'Hải Lăng', 'ward_normalized': 'Hải Ba'}
# Actual   : {'province': '', 'district': 'Hải Lăng', 'ward': '', 'province_normalized': '', 'district_normalized': 'Hải Lăng', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.004732s
# ------------------------------
# Case #164 ---
# Input    : 'XThạnh Đức, HGò Dầ6u, T Tây Ninh'
# Expected : {'district': 'Gò Dầu', 'ward': 'Thạnh Đức', 'province': 'Tây Ninh', 'province_normalized': 'Tây Ninh', 'district_normalized': 'Gò Dầu', 'ward_normalized': 'Thạnh Đức'}
# Actual   : {'province': 'Tây Ninh', 'district': '', 'ward': 'Thạnh Đức', 'province_normalized': 'Tây Ninh', 'district_normalized': '', 'ward_normalized': 'Thạnh Đức'}
# Correct  : 2/3
# Time     : 0.006967s
# ------------------------------
# Case #165 ---
# Input    : 'X.Thài Phìn Tủng, Huyện ĐồGg Van,  Hà Gxiang'
# Expected : {'district': 'Đồng Văn', 'ward': 'Thài Phìn Tủng', 'province': 'Hà Giang', 'province_normalized': 'Hà Giang', 'district_normalized': 'Đồng Văn', 'ward_normalized': 'Thài Phìn Tủng'}
# Actual   : {'province': 'Hà Giang', 'district': '', 'ward': 'Thài Phìn Tủng', 'province_normalized': 'Hà Giang', 'district_normalized': '', 'ward_normalized': 'Thài Phìn Tủng'}
# Correct  : 2/3
# Time     : 0.022476s
# ------------------------------
# Case #166 ---
# Input    : 'XãBù Gia Mập,,T Bình Phước'
# Expected : {'district': '', 'ward': 'Bù Gia Mập', 'province': 'Bình Phước', 'province_normalized': 'Bình Phước', 'district_normalized': '', 'ward_normalized': 'Bù Gia Mập'}
# Actual   : {'province': 'Bình Phước', 'district': 'Bù Gia Mập', 'ward': '', 'province_normalized': 'Bình Phước', 'district_normalized': 'Bù Gia Mập', 'ward_normalized': ''}
# Correct  : 1/3
# Time     : 0.001084s
# ------------------------------
# Case #167 ---
# Input    : 'Xã Mỹ Lương Yên Lập '
# Expected : {'district': 'Yên Lập', 'ward': 'Mỹ Lương', 'province': '', 'province_normalized': '', 'district_normalized': 'Yên Lập', 'ward_normalized': 'Mỹ Lương'}
# Actual   : {'province': 'Hưng Yên', 'district': '', 'ward': '', 'province_normalized': 'Hưng Yên', 'district_normalized': '', 'ward_normalized': ''}
# Correct  : 0/3
# Time     : 0.002363s
# ------------------------------
# Case #170 ---
# Input    : ' Tam GiangNăm CănT.Cà Mau'
# Expected : {'district': 'Năm Căn', 'ward': 'Tam Giang', 'province': 'Cà Mau', 'province_normalized': 'Cà Mau', 'district_normalized': 'Năm Căn', 'ward_normalized': 'Tam Giang'}
# Actual   : {'province': 'Cà Mau', 'district': '', 'ward': 'Tam Giang', 'province_normalized': 'Cà Mau', 'district_normalized': '', 'ward_normalized': 'Tam Giang'}
# Correct  : 2/3
# Time     : 0.003208s
# ------------------------------
# Case #173 ---
# Input    : 'XTân Thạnh, hAn Minh '
# Expected : {'district': 'An Minh', 'ward': 'Tân Thạnh', 'province': '', 'province_normalized': '', 'district_normalized': 'An Minh', 'ward_normalized': 'Tân Thạnh'}
# Actual   : {'province': '', 'district': 'An Minh', 'ward': '', 'province_normalized': '', 'district_normalized': 'An Minh', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.010379s
# ------------------------------
# Case #174 ---
# Input    : 'X Cam Bình, Thành FhốCam Rah,  Khánh Hòa'
# Expected : {'district': 'Cam Ranh', 'ward': 'Cam Bình', 'province': 'Khánh Hòa', 'province_normalized': 'Khánh Hòa', 'district_normalized': 'Cam Ranh', 'ward_normalized': 'Cam Bình'}
# Actual   : {'province': 'Khánh Hòa', 'district': '', 'ward': 'Cam Bình', 'province_normalized': 'Khánh Hòa', 'district_normalized': '', 'ward_normalized': 'Cam Bình'}
# Correct  : 2/3
# Time     : 0.008279s
# ------------------------------
# Case #176 ---
# Input    : ' Minh Tân,h.Lưng Tai,'
# Expected : {'district': 'Lương Tài', 'ward': 'Minh Tân', 'province': '', 'province_normalized': '', 'district_normalized': 'Lương Tài', 'ward_normalized': 'Minh Tân'}
# Actual   : {'province': '', 'district': 'Tân Hưng', 'ward': '', 'province_normalized': '', 'district_normalized': 'Tân Hưng', 'ward_normalized': ''}
# Correct  : 1/3
# Time     : 0.026173s
# ------------------------------
# Case #177 ---
# Input    : 'XãQuỳn1 Lâm, H. Quỳnh Phụ,  Thai Bình'
# Expected : {'district': 'Quỳnh Phụ', 'ward': 'Quỳnh Lâm', 'province': 'Thái Bình', 'province_normalized': 'Thái Bình', 'district_normalized': 'Quỳnh Phụ', 'ward_normalized': 'Quỳnh Lâm'}
# Actual   : {'province': 'Thái Bình', 'district': 'Quỳnh Phụ', 'ward': '', 'province_normalized': 'Thái Bình', 'district_normalized': 'Quỳnh Phụ', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.001505s
# ------------------------------
# Case #188 ---
# Input    : '  Đông Giang T Quảyg Nm'
# Expected : {'district': 'Đông Giang', 'ward': '', 'province': 'Quảng Nam', 'province_normalized': 'Quảng Nam', 'district_normalized': 'Đông Giang', 'ward_normalized': ''}
# Actual   : {'province': '', 'district': 'Đông Giang', 'ward': '', 'province_normalized': '', 'district_normalized': 'Đông Giang', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.032329s
# ------------------------------
# Case #191 ---
# Input    : 'Xan Tiến, H. An Lão, '
# Expected : {'district': 'An Lão', 'ward': 'An Tiến', 'province': '', 'province_normalized': '', 'district_normalized': 'An Lão', 'ward_normalized': 'An Tiến'}
# Actual   : {'province': '', 'district': 'An Lão', 'ward': '', 'province_normalized': '', 'district_normalized': 'An Lão', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.008051s
# ------------------------------
# Case #194 ---
# Input    : 'X. HoDng Quỳ,,9hanh Hóa'
# Expected : {'district': '', 'ward': 'Hoằng Quỳ', 'province': 'Thanh Hóa', 'province_normalized': 'Thanh Hóa', 'district_normalized': '', 'ward_normalized': 'Hoằng Quỳ'}
# Actual   : {'province': 'Thanh Hóa', 'district': '', 'ward': '', 'province_normalized': 'Thanh Hóa', 'district_normalized': '', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.011955s
# ------------------------------
# Case #195 ---
# Input    : 'XãBình Chau,  Bình Sơn, Tỉnh Quảng Ngãi'
# Expected : {'district': 'Bình Sơn', 'ward': 'Bình Châu', 'province': 'Quảng Ngãi', 'province_normalized': 'Quảng Ngãi', 'district_normalized': 'Bình Sơn', 'ward_normalized': 'Bình Châu'}
# Actual   : {'province': 'Quảng Ngãi', 'district': 'Sơn Tịnh', 'ward': '', 'province_normalized': 'Quảng Ngãi', 'district_normalized': 'Sơn Tịnh', 'ward_normalized': ''}
# Correct  : 1/3
# Time     : 0.001206s
# ------------------------------
# Case #196 ---
# Input    : 'X.Tân Tiến,H.Đồng Phú,'
# Expected : {'district': 'Đồng Phú', 'ward': 'Tân Tiến', 'province': '', 'province_normalized': '', 'district_normalized': 'Đồng Phú', 'ward_normalized': 'Tân Tiến'}
# Actual   : {'province': '', 'district': 'Đồng Phú', 'ward': '', 'province_normalized': '', 'district_normalized': 'Đồng Phú', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.009245s
# ------------------------------
# Case #198 ---
# Input    : 'PHoà Quý Q.ngũ Hành sơn Đà Nẵng'
# Expected : {'district': 'Ngũ Hành Sơn', 'ward': 'Hoà Quý', 'province': 'Đà Nẵng', 'province_normalized': 'Đà Nẵng', 'district_normalized': 'Ngũ Hành Sơn', 'ward_normalized': 'Hoà Quý'}
# Actual   : {'province': 'Đà Nẵng', 'district': 'Ngũ Hành Sơn', 'ward': '', 'province_normalized': 'Đà Nẵng', 'district_normalized': 'Ngũ Hành Sơn', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.001158s
# ------------------------------
# Case #200 ---
# Input    : 'X Phong Quang, HKuyệnVị Xuyên, Tỉnh Hà Giang'
# Expected : {'district': 'Vị Xuyên', 'ward': 'Phong Quang', 'province': 'Hà Giang', 'province_normalized': 'Hà Giang', 'district_normalized': 'Vị Xuyên', 'ward_normalized': 'Phong Quang'}
# Actual   : {'province': 'Hà Giang', 'district': '', 'ward': 'Phong Quang', 'province_normalized': 'Hà Giang', 'district_normalized': '', 'ward_normalized': 'Phong Quang'}
# Correct  : 2/3
# Time     : 0.016333s
# ------------------------------
# Case #201 ---
# Input    : 'XãV Ninh, Kiên Xương,'
# Expected : {'district': 'Kiến Xương', 'ward': 'Vũ Ninh', 'province': '', 'province_normalized': '', 'district_normalized': 'Kiến Xương', 'ward_normalized': 'Vũ Ninh'}
# Actual   : {'province': '', 'district': 'Kiến Xương', 'ward': '', 'province_normalized': '', 'district_normalized': 'Kiến Xương', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.009897s
# ------------------------------
# Case #206 ---
# Input    : 'X.Thiết Kế,H.Bá Thước,'
# Expected : {'district': 'Bá Thước', 'ward': 'Thiết Kế', 'province': '', 'province_normalized': '', 'district_normalized': 'Bá Thước', 'ward_normalized': 'Thiết Kế'}
# Actual   : {'province': '', 'district': 'Bá Thước', 'ward': '', 'province_normalized': '', 'district_normalized': 'Bá Thước', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.009559s
# ------------------------------
# Case #207 ---
# Input    : 'Phưng Khâm Thiên Quận Đ.Đa T.Phố HàNội'
# Expected : {'district': 'Đống Đa', 'ward': 'Khâm Thiên', 'province': 'Hà Nội', 'province_normalized': 'Hà Nội', 'district_normalized': 'Đống Đa', 'ward_normalized': 'Khâm Thiên'}
# Actual   : {'province': 'Hà Nội', 'district': '', 'ward': 'Khâm Thiên', 'province_normalized': 'Hà Nội', 'district_normalized': '', 'ward_normalized': 'Khâm Thiên'}
# Correct  : 2/3
# Time     : 0.032225s
# ------------------------------
# Case #208 ---
# Input    : 'X Quỳnh Nuyên,,T. Thái Bình'
# Expected : {'district': '', 'ward': 'Quỳnh Nguyên', 'province': 'Thái Bình', 'province_normalized': 'Thái Bình', 'district_normalized': '', 'ward_normalized': 'Quỳnh Nguyên'}
# Actual   : {'province': 'Thái Bình', 'district': '', 'ward': '', 'province_normalized': 'Thái Bình', 'district_normalized': '', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.010670s
# ------------------------------
# Case #209 ---
# Input    : 'XVnh Hung, , T.Thanh Hóa'
# Expected : {'district': '', 'ward': 'Vĩnh Hùng', 'province': 'Thanh Hóa', 'province_normalized': 'Thanh Hóa', 'district_normalized': '', 'ward_normalized': 'Vĩnh Hùng'}
# Actual   : {'province': 'Thanh Hóa', 'district': '', 'ward': '', 'province_normalized': 'Thanh Hóa', 'district_normalized': '', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.013833s
# ------------------------------
# Case #210 ---
# Input    : 'X.Tăng Thanh, H Yên Thành, '
# Expected : {'district': 'Yên Thành', 'ward': 'Tăng Thành', 'province': '', 'province_normalized': '', 'district_normalized': 'Yên Thành', 'ward_normalized': 'Tăng Thành'}
# Actual   : {'province': '', 'district': 'Yên Thành', 'ward': '', 'province_normalized': '', 'district_normalized': 'Yên Thành', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.011695s
# ------------------------------
# Case #211 ---
# Input    : 'XãTrung Lập,  Vĩnh Bảo,7 '
# Expected : {'district': 'Vĩnh Bảo', 'ward': 'Trung Lập', 'province': '', 'province_normalized': '', 'district_normalized': 'Vĩnh Bảo', 'ward_normalized': 'Trung Lập'}
# Actual   : {'province': '', 'district': 'Vĩnh Bảo', 'ward': '', 'province_normalized': '', 'district_normalized': 'Vĩnh Bảo', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.015857s
# ------------------------------
# Case #216 ---
# Input    : 'QX.Tân Hưng Tây, Ph8 Tân,'
# Expected : {'district': 'Phú Tân', 'ward': 'Tân Hưng Tây', 'province': '', 'province_normalized': '', 'district_normalized': 'Phú Tân', 'ward_normalized': 'Tân Hưng Tây'}
# Actual   : {'province': '', 'district': 'Phú Tân', 'ward': '', 'province_normalized': '', 'district_normalized': 'Phú Tân', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.016141s
# ------------------------------
# Case #221 ---
# Input    : 'XBình PhúN  Càng Long, T.u trà Vinh'
# Expected : {'district': 'Càng Long', 'ward': 'Bình Phú', 'province': 'Trà Vinh', 'province_normalized': 'Trà Vinh', 'district_normalized': 'Càng Long', 'ward_normalized': 'Bình Phú'}
# Actual   : {'province': 'Trà Vinh', 'district': 'Càng Long', 'ward': '', 'province_normalized': 'Trà Vinh', 'district_normalized': 'Càng Long', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.001105s
# ------------------------------
# Case #223 ---
# Input    : 'XHòa Bqc, HDi Linh, '
# Expected : {'district': 'Di Linh', 'ward': 'Hòa Bắc', 'province': '', 'province_normalized': '', 'district_normalized': 'Di Linh', 'ward_normalized': 'hòa bắc'}
# Actual   : {'province': '', 'district': 'Di Linh', 'ward': '', 'province_normalized': '', 'district_normalized': 'Di Linh', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.008315s
# ------------------------------
# Case #225 ---
# Input    : 'Đai TanHuyện Đại ộc,TỉnhQuảng Nam'
# Expected : {'district': 'Đại Lộc', 'ward': 'Đại Tân', 'province': 'Quảng Nam', 'province_normalized': 'Quảng Nam', 'district_normalized': 'Đại Lộc', 'ward_normalized': 'Đại Tân'}
# Actual   : {'province': 'Quảng Nam', 'district': 'Đại Lộc', 'ward': '', 'province_normalized': 'Quảng Nam', 'district_normalized': 'Đại Lộc', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.001148s
# ------------------------------
# Case #231 ---
# Input    : 'XKHoan Sơn,TiênDu,Tỉnhbac Ninh'
# Expected : {'district': 'Tiên Du', 'ward': 'Hoàn Sơn', 'province': 'Bắc Ninh', 'province_normalized': 'Bắc Ninh', 'district_normalized': 'Tiên Du', 'ward_normalized': 'Hoàn Sơn'}
# Actual   : {'province': 'Bắc Ninh', 'district': 'Tiên Du', 'ward': '', 'province_normalized': 'Bắc Ninh', 'district_normalized': 'Tiên Du', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.001133s
# ------------------------------
# Case #232 ---
# Input    : ' Hải An  Hải Lăng TQdung trị'
# Expected : {'district': 'Hải Lăng', 'ward': 'Hải An', 'province': 'Quảng Trị', 'province_normalized': 'Quảng Trị', 'district_normalized': 'Hải Lăng', 'ward_normalized': 'Hải An'}
# Actual   : {'province': '', 'district': 'Hải Lăng', 'ward': '', 'province_normalized': '', 'district_normalized': 'Hải Lăng', 'ward_normalized': ''}
# Correct  : 1/3
# Time     : 0.027622s
# ------------------------------
# Case #234 ---
# Input    : 'Thị trấn Hai Riêng H Sông Hinh '
# Expected : {'district': 'Sông Hinh', 'ward': 'Hai Riêng', 'province': '', 'province_normalized': '', 'district_normalized': 'Sông Hinh', 'ward_normalized': 'Hai Riêng'}
# Actual   : {'province': '', 'district': 'Sông Hinh', 'ward': '', 'province_normalized': '', 'district_normalized': 'Sông Hinh', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.012583s
# ------------------------------
# Case #235 ---
# Input    : 'X. Diễn Thành Huyện Diên Châu '
# Expected : {'district': 'Diễn Châu', 'ward': 'Diễn Thành', 'province': '', 'province_normalized': '', 'district_normalized': 'Diễn Châu', 'ward_normalized': 'Diễn Thành'}
# Actual   : {'province': '', 'district': 'Diễn Châu', 'ward': '', 'province_normalized': '', 'district_normalized': 'Diễn Châu', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.013063s
# ------------------------------
# Case #237 ---
# Input    : 'Xã thanh Vĩnh Đông, HuyệnChâu Thành, TLong An'
# Expected : {'district': 'Châu Thành', 'ward': 'Thanh Vĩnh Đông', 'province': 'Long An', 'province_normalized': 'Long An', 'district_normalized': 'Châu Thành', 'ward_normalized': 'Thanh Vĩnh Đông'}
# Actual   : {'province': 'Long An', 'district': 'Châu Thành', 'ward': 'Vĩnh Công', 'province_normalized': 'Long An', 'district_normalized': 'Châu Thành', 'ward_normalized': 'Vĩnh Công'}
# Correct  : 2/3
# Time     : 0.000947s
# ------------------------------
# Case #238 ---
# Input    : 'X.Chê La,,T.Hà GianZ'
# Expected : {'district': '', 'ward': 'Chế Là', 'province': 'Hà Giang', 'province_normalized': 'Hà Giang', 'district_normalized': '', 'ward_normalized': 'Chế Là'}
# Actual   : {'province': 'Hà Giang', 'district': '', 'ward': '', 'province_normalized': 'Hà Giang', 'district_normalized': '', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.007999s
# ------------------------------
# Case #239 ---
# Input    : 'Hôno Sỹ  Tỉnh Cao Bằng'
# Expected : {'district': '', 'ward': 'Hồng Sỹ', 'province': 'Cao Bằng', 'province_normalized': 'Cao Bằng', 'district_normalized': '', 'ward_normalized': 'Hồng Sỹ'}
# Actual   : {'province': 'Cao Bằng', 'district': '', 'ward': '', 'province_normalized': 'Cao Bằng', 'district_normalized': '', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.007228s
# ------------------------------
# Case #245 ---
# Input    : 'Xã Trịnh Tường H Bát Xát '
# Expected : {'district': 'Bát Xát', 'ward': 'Trịnh Tường', 'province': '', 'province_normalized': '', 'district_normalized': 'Bát Xát', 'ward_normalized': 'Trịnh Tường'}
# Actual   : {'province': '', 'district': 'Bát Xát', 'ward': '', 'province_normalized': '', 'district_normalized': 'Bát Xát', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.009095s
# ------------------------------
# Case #248 ---
# Input    : 'P4 T.Ph9ốĐông Hà '
# Expected : {'district': 'Đông Hà', 'ward': '4', 'province': '', 'province_normalized': '', 'district_normalized': 'Đông Hà', 'ward_normalized': 4}
# Actual   : {'province': '', 'district': '', 'ward': '', 'province_normalized': '', 'district_normalized': '', 'ward_normalized': ''}
# Correct  : 1/3
# Time     : 0.030672s
# ------------------------------
# Case #252 ---
# Input    : 'F.07, Q6, '
# Expected : {'district': '6', 'ward': '07', 'province': '', 'province_normalized': '', 'district_normalized': '6', 'ward_normalized': 7}
# Actual   : {'province': '', 'district': '', 'ward': '', 'province_normalized': '', 'district_normalized': '', 'ward_normalized': ''}
# Correct  : 1/3
# Time     : 0.010393s
# ------------------------------
# Case #255 ---
# Input    : ' Long Thắng, Huyn Lai ung, '
# Expected : {'district': 'Lai Vung', 'ward': 'Long Thắng', 'province': '', 'province_normalized': '', 'district_normalized': 'Lai Vung', 'ward_normalized': 'Long Thắng'}
# Actual   : {'province': '', 'district': 'Lai Vung', 'ward': '', 'province_normalized': '', 'district_normalized': 'Lai Vung', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.008966s
# ------------------------------
# Case #258 ---
# Input    : ' Bằng Lng,,T.Bắc Kạn'
# Expected : {'district': '', 'ward': 'Bằng Lũng', 'province': 'Bắc Kạn', 'province_normalized': 'Bắc Kạn', 'district_normalized': '', 'ward_normalized': 'Bằng Lũng'}
# Actual   : {'province': 'Bắc Kạn', 'district': '', 'ward': 'Bằng Lãng', 'province_normalized': 'Bắc Kạn', 'district_normalized': '', 'ward_normalized': 'Bằng Lãng'}
# Correct  : 2/3
# Time     : 0.001936s
# ------------------------------
# Case #261 ---
# Input    : 'X. Tân An, HuyệnThnh Hà, '
# Expected : {'district': 'Thanh Hà', 'ward': 'Tân An', 'province': '', 'province_normalized': '', 'district_normalized': 'Thanh Hà', 'ward_normalized': 'Tân An'}
# Actual   : {'province': '', 'district': 'Thanh Hà', 'ward': '', 'province_normalized': '', 'district_normalized': 'Thanh Hà', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.008521s
# ------------------------------
# Case #263 ---
# Input    : 'vĩnh Hưng, , Long An'
# Expected : {'district': '', 'ward': 'Vĩnh Hưng', 'province': 'Long An', 'province_normalized': 'Long An', 'district_normalized': '', 'ward_normalized': 'Vĩnh Hưng'}
# Actual   : {'province': 'Long An', 'district': 'Vĩnh Hưng', 'ward': '', 'province_normalized': 'Long An', 'district_normalized': 'Vĩnh Hưng', 'ward_normalized': ''}
# Correct  : 1/3
# Time     : 0.000549s
# ------------------------------
# Case #264 ---
# Input    : 'Phường 04,,Thành phốHồ Chi Minh'
# Expected : {'district': '', 'ward': '04', 'province': 'Hồ Chí Minh', 'province_normalized': 'Hồ Chí Minh', 'district_normalized': '', 'ward_normalized': 4}
# Actual   : {'province': '', 'district': '', 'ward': '', 'province_normalized': '', 'district_normalized': '', 'ward_normalized': ''}
# Correct  : 1/3
# Time     : 0.037879s
# ------------------------------
# Case #265 ---
# Input    : 'Xã Nâm Ntừ  Nậm Pồ '
# Expected : {'district': 'Nậm Pồ', 'ward': 'Nậm Nhừ', 'province': '', 'province_normalized': '', 'district_normalized': 'Nậm Pồ', 'ward_normalized': 'Nậm Nhừ'}
# Actual   : {'province': '', 'district': 'Nậm Pồ', 'ward': '', 'province_normalized': '', 'district_normalized': 'Nậm Pồ', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.007608s
# ------------------------------
# Case #270 ---
# Input    : 'Phường Hoài Hảo,T.Xã.Hoai Nhơn,TBình Đinh'
# Expected : {'district': 'Hoài Nhơn', 'ward': 'Hoài Hảo', 'province': 'Bình Định', 'province_normalized': 'Bình Định', 'district_normalized': 'Hoài Nhơn', 'ward_normalized': 'Hoài Hảo'}
# Actual   : {'province': 'Bình Định', 'district': 'Hoài Nhơn', 'ward': '', 'province_normalized': 'Bình Định', 'district_normalized': 'Hoài Nhơn', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.001355s
# ------------------------------
# Case #272 ---
# Input    : 'P Ea Tam T.P Buôn Ma Thuột TỉnĐắk Llk'
# Expected : {'district': 'Buôn Ma Thuột', 'ward': 'Ea Tam', 'province': 'Đắk Lắk', 'province_normalized': 'Đắk Lắk', 'district_normalized': 'Buôn Ma Thuột', 'ward_normalized': 'Ea Tam'}
# Actual   : {'province': '', 'district': '', 'ward': '', 'province_normalized': '', 'district_normalized': '', 'ward_normalized': ''}
# Correct  : 0/3
# Time     : 0.041800s
# ------------------------------
# Case #274 ---
# Input    : 'F Tân Dân, T.Xã.Nghi Sơn, TỉnhThanh Hóa'
# Expected : {'district': 'Nghi Sơn', 'ward': 'Tân Dân', 'province': 'Thanh Hóa', 'province_normalized': 'Thanh Hóa', 'district_normalized': 'Nghi Sơn', 'ward_normalized': 'Tân Dân'}
# Actual   : {'province': 'Thanh Hóa', 'district': 'Quan Sơn', 'ward': '', 'province_normalized': 'Thanh Hóa', 'district_normalized': 'Quan Sơn', 'ward_normalized': ''}
# Correct  : 1/3
# Time     : 0.002042s
# ------------------------------
# Case #275 ---
# Input    : 'XNam Cát, HuyệnNam đàn, '
# Expected : {'district': 'Nam Đàn', 'ward': 'Nam Cát', 'province': '', 'province_normalized': '', 'district_normalized': 'Nam Đàn', 'ward_normalized': 'Nam Cát'}
# Actual   : {'province': '', 'district': 'Nam Đàn', 'ward': '', 'province_normalized': '', 'district_normalized': 'Nam Đàn', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.008908s
# ------------------------------
# Case #276 ---
# Input    : 'Xã Vị Tân  Vị Than '
# Expected : {'district': 'Vị Thanh', 'ward': 'Vị Tân', 'province': '', 'province_normalized': '', 'district_normalized': 'Vị Thanh', 'ward_normalized': 'Vị Tân'}
# Actual   : {'province': '', 'district': 'Vị Thanh', 'ward': '', 'province_normalized': '', 'district_normalized': 'Vị Thanh', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.008369s
# ------------------------------
# Case #277 ---
# Input    : 'X My Thành Bac, HuyệnCai Lậy, '
# Expected : {'district': 'Cai Lậy', 'ward': 'Mỹ Thành Bắc', 'province': '', 'province_normalized': '', 'district_normalized': 'Cai Lậy', 'ward_normalized': 'Mỹ Thành Bắc'}
# Actual   : {'province': '', 'district': 'Cai Lậy', 'ward': '', 'province_normalized': '', 'district_normalized': 'Cai Lậy', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.013631s
# ------------------------------
# Case #278 ---
# Input    : 'XCư Drămb H.Krông Bông '
# Expected : {'district': 'Krông Bông', 'ward': 'Cư Drăm', 'province': '', 'province_normalized': '', 'district_normalized': 'Krông Bông', 'ward_normalized': 'Cư Drăm'}
# Actual   : {'province': '', 'district': 'Krông Bông', 'ward': '', 'province_normalized': '', 'district_normalized': 'Krông Bông', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.010349s
# ------------------------------
# Case #281 ---
# Input    : ' Khả cửu, H. Thanh Srn, '
# Expected : {'district': 'Thanh Sơn', 'ward': 'Khả Cửu', 'province': '', 'province_normalized': '', 'district_normalized': 'Thanh Sơn', 'ward_normalized': 'Khả Cửu'}
# Actual   : {'province': '', 'district': 'Thanh Sơn', 'ward': '', 'province_normalized': '', 'district_normalized': 'Thanh Sơn', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.007577s
# ------------------------------
# Case #284 ---
# Input    : 'Thị Trấn Nông Trường Việt lâm,Vị Xuyen,Ha Giang'
# Expected : {'district': 'Vị Xuyên', 'ward': 'Nông Trường Việt Lâm', 'province': 'Hà Giang', 'province_normalized': 'Hà Giang', 'district_normalized': 'Vị Xuyên', 'ward_normalized': 'Nông Trường Việt Lâm'}
# Actual   : {'province': 'Hà Giang', 'district': 'Vị Xuyên', 'ward': 'Việt Lâm', 'province_normalized': 'Hà Giang', 'district_normalized': 'Vị Xuyên', 'ward_normalized': 'Việt Lâm'}
# Correct  : 2/3
# Time     : 0.000745s
# ------------------------------
# Case #285 ---
# Input    : ', Q11, Hồ Chí Minh'
# Expected : {'district': '11', 'ward': '', 'province': 'Hồ Chí Minh', 'province_normalized': 'Hồ Chí Minh', 'district_normalized': '11', 'ward_normalized': ''}
# Actual   : {'province': 'Hồ Chí Minh', 'district': '', 'ward': '', 'province_normalized': 'Hồ Chí Minh', 'district_normalized': '', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.001918s
# ------------------------------
# Case #287 ---
# Input    : 'F.LoWng Binh, TpThủ Đưc, TPHCM'
# Expected : {'district': 'Thủ Đức', 'ward': 'Long Bình', 'province': 'Hồ Chí Minh', 'province_normalized': 'Hồ Chí Minh', 'district_normalized': 'Thủ Đức', 'ward_normalized': 'Long Bình'}
# Actual   : {'province': 'Hồ Chí Minh', 'district': 'Thủ Đức', 'ward': '', 'province_normalized': 'Hồ Chí Minh', 'district_normalized': 'Thủ Đức', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.001766s
# ------------------------------
# Case #288 ---
# Input    : 'Xã Đông cường, h.Đông Hưng, '
# Expected : {'district': 'Đông Hưng', 'ward': 'Đông Cường', 'province': '', 'province_normalized': '', 'district_normalized': 'Đông Hưng', 'ward_normalized': 'Đông Cường'}
# Actual   : {'province': '', 'district': 'Đông Hưng', 'ward': '', 'province_normalized': '', 'district_normalized': 'Đông Hưng', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.010173s
# ------------------------------
# Case #292 ---
# Input    : ',HyệnĐại Lộc,TỉnhQuảng Nam'
# Expected : {'district': 'Đại Lộc', 'ward': '', 'province': 'Quảng Nam', 'province_normalized': 'Quảng Nam', 'district_normalized': 'Đại Lộc', 'ward_normalized': ''}
# Actual   : {'province': 'Quảng Nam', 'district': '', 'ward': '', 'province_normalized': 'Quảng Nam', 'district_normalized': '', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.004270s
# ------------------------------
# Case #295 ---
# Input    : 'PhườngHà Mãn, T.X.Thuận Thành, '
# Expected : {'district': 'Thuận Thành', 'ward': 'Hà Mãn', 'province': '', 'province_normalized': '', 'district_normalized': 'Thuận Thành', 'ward_normalized': 'Hà Mãn'}
# Actual   : {'province': '', 'district': 'Thuận Thành', 'ward': '', 'province_normalized': '', 'district_normalized': 'Thuận Thành', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.009002s
# ------------------------------
# Case #297 ---
# Input    : 'x. Nam Thai A, AZBiên,Tỉnh Kiên Giang'
# Expected : {'district': 'An Biên', 'ward': 'Nam Thái A', 'province': 'Kiên Giang', 'province_normalized': 'Kiên Giang', 'district_normalized': 'An Biên', 'ward_normalized': 'Nam Thái A'}
# Actual   : {'province': 'Kiên Giang', 'district': 'An Biên', 'ward': 'Nam Thái', 'province_normalized': 'Kiên Giang', 'district_normalized': 'An Biên', 'ward_normalized': 'Nam Thái'}
# Correct  : 2/3
# Time     : 0.001825s
# ------------------------------
# Case #304 ---
# Input    : 'Nghi Sơ6n, T.X. Nghi Sơn, Thhanh Hóa'
# Expected : {'district': 'Nghi Sơn', 'ward': 'Nghi Sơn', 'province': 'Thanh Hóa', 'province_normalized': 'Thanh Hóa', 'district_normalized': 'Nghi Sơn', 'ward_normalized': 'Nghi Sơn'}
# Actual   : {'province': 'Thanh Hóa', 'district': 'Quan Sơn', 'ward': '', 'province_normalized': 'Thanh Hóa', 'district_normalized': 'Quan Sơn', 'ward_normalized': ''}
# Correct  : 1/3
# Time     : 0.002051s
# ------------------------------
# Case #306 ---
# Input    : 'TT Đạ Tẻh, , T. Lâm Đồng'
# Expected : {'district': '', 'ward': 'Đạ Tẻh', 'province': 'Lâm Đồng', 'province_normalized': 'Lâm Đồng', 'district_normalized': '', 'ward_normalized': 'Đạ Tẻh'}
# Actual   : {'province': 'Lâm Đồng', 'district': 'Đạ Tẻh', 'ward': '', 'province_normalized': 'Lâm Đồng', 'district_normalized': 'Đạ Tẻh', 'ward_normalized': ''}
# Correct  : 1/3
# Time     : 0.000569s
# ------------------------------
# Case #309 ---
# Input    : 'X.H Mỗ, Đan PhTượng,'
# Expected : {'district': 'Đan Phượng', 'ward': 'Hạ Mỗ', 'province': '', 'province_normalized': '', 'district_normalized': 'Đan Phượng', 'ward_normalized': 'Hạ Mỗ'}
# Actual   : {'province': '', 'district': 'Đan Phượng', 'ward': '', 'province_normalized': '', 'district_normalized': 'Đan Phượng', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.008129s
# ------------------------------
# Case #312 ---
# Input    : 'Xã Quang Tiếns6 Tân Yên, '
# Expected : {'district': 'Tân Yên', 'ward': 'Quang Tiến', 'province': '', 'province_normalized': '', 'district_normalized': 'Tân Yên', 'ward_normalized': 'Quang Tiến'}
# Actual   : {'province': '', 'district': 'Tân Yên', 'ward': '', 'province_normalized': '', 'district_normalized': 'Tân Yên', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.007635s
# ------------------------------
# Case #313 ---
# Input    : 'Thị Trấn Kẻ Sặt H.Binh giang THải Dưong'
# Expected : {'district': 'Bình Giang', 'ward': 'Kẻ Sặt', 'province': 'Hải Dương', 'province_normalized': 'Hải Dương', 'district_normalized': 'Bình Giang', 'ward_normalized': 'Kẻ Sặt'}
# Actual   : {'province': 'Hải Dương', 'district': 'Ninh Giang', 'ward': '', 'province_normalized': 'Hải Dương', 'district_normalized': 'Ninh Giang', 'ward_normalized': ''}
# Correct  : 1/3
# Time     : 0.002440s
# ------------------------------
# Case #314 ---
# Input    : 'Xã Lương Hòa,HuyệnBen Lức,'
# Expected : {'district': 'Bến Lức', 'ward': 'Lương Hòa', 'province': '', 'province_normalized': '', 'district_normalized': 'Bến Lức', 'ward_normalized': 'Lương Hòa'}
# Actual   : {'province': '', 'district': 'Bến Lức', 'ward': '', 'province_normalized': '', 'district_normalized': 'Bến Lức', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.008344s
# ------------------------------
# Case #315 ---
# Input    : 'X.Tân Son,hchợ QMới,'
# Expected : {'district': 'Chợ Mới', 'ward': 'Tân Sơn', 'province': '', 'province_normalized': '', 'district_normalized': 'Chợ Mới', 'ward_normalized': 'Tân Sơn'}
# Actual   : {'province': '', 'district': 'Chợ Mới', 'ward': '', 'province_normalized': '', 'district_normalized': 'Chợ Mới', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.009014s
# ------------------------------
# Case #316 ---
# Input    : 'Quách Phẩm Bắc, , Cà Mzu'
# Expected : {'district': '', 'ward': 'Quách Phẩm Bắc', 'province': 'Cà Mau', 'province_normalized': 'Cà Mau', 'district_normalized': '', 'ward_normalized': 'Quách Phẩm Bắc'}
# Actual   : {'province': 'Cà Mau', 'district': '', 'ward': 'Quách Phẩm', 'province_normalized': 'Cà Mau', 'district_normalized': '', 'ward_normalized': 'Quách Phẩm'}
# Correct  : 2/3
# Time     : 0.002144s
# ------------------------------
# Case #322 ---
# Input    : 'XMiền Đồi,LaZc Sơn,'
# Expected : {'district': 'Lạc Sơn', 'ward': 'Miền Đồi', 'province': '', 'province_normalized': '', 'district_normalized': 'Lạc Sơn', 'ward_normalized': 'Miền Đồi'}
# Actual   : {'province': '', 'district': 'Quan Sơn', 'ward': '', 'province_normalized': '', 'district_normalized': 'Quan Sơn', 'ward_normalized': ''}
# Correct  : 1/3
# Time     : 0.011563s
# ------------------------------
# Case #331 ---
# Input    : 'Tích Sơn T.Phốvinh Yên t vĩnh phúc'
# Expected : {'district': 'Vĩnh Yên', 'ward': 'Tích Sơn', 'province': 'Vĩnh Phúc', 'province_normalized': 'Vĩnh Phúc', 'district_normalized': 'Vĩnh Yên', 'ward_normalized': 'Tích Sơn'}
# Actual   : {'province': 'Vĩnh Phúc', 'district': '', 'ward': 'Tích Sơn', 'province_normalized': 'Vĩnh Phúc', 'district_normalized': '', 'ward_normalized': 'Tích Sơn'}
# Correct  : 2/3
# Time     : 0.012577s
# ------------------------------
# Case #332 ---
# Input    : 'X.Hòa Trị Huzyen hú Hoa TPhú Yên'
# Expected : {'district': 'Phú Hoà', 'ward': 'Hòa Trị', 'province': 'Phú Yên', 'province_normalized': 'Phú Yên', 'district_normalized': 'Phú Hoà', 'ward_normalized': 'Hòa Trị'}
# Actual   : {'province': 'Phú Yên', 'district': '', 'ward': 'Phú Hoà', 'province_normalized': 'Phú Yên', 'district_normalized': '', 'ward_normalized': 'Phú Hoà'}
# Correct  : 1/3
# Time     : 0.002207s
# ------------------------------
# Case #333 ---
# Input    : 'XLa Sơn H. Binh lục '
# Expected : {'district': 'Bình Lục', 'ward': 'La Sơn', 'province': '', 'province_normalized': '', 'district_normalized': 'Bình Lục', 'ward_normalized': 'La Sơn'}
# Actual   : {'province': '', 'district': 'Bình Lục', 'ward': '', 'province_normalized': '', 'district_normalized': 'Bình Lục', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.006529s
# ------------------------------
# Case #336 ---
# Input    : 'X. Bok Tới H Hoài Ân  Bìh Định'
# Expected : {'district': 'Hoài Ân', 'ward': 'Bok Tới', 'province': 'Bình Định', 'province_normalized': 'Bình Định', 'district_normalized': 'Hoài Ân', 'ward_normalized': 'Bok Tới'}
# Actual   : {'province': 'Bình Định', 'district': '', 'ward': 'Bok Tới', 'province_normalized': 'Bình Định', 'district_normalized': '', 'ward_normalized': 'Bok Tới'}
# Correct  : 2/3
# Time     : 0.006079s
# ------------------------------
# Case #338 ---
# Input    : 'Bình Sa HuyệnThăng Bình '
# Expected : {'district': 'Thăng Bình', 'ward': 'Bình Sa', 'province': '', 'province_normalized': '', 'district_normalized': 'Thăng Bình', 'ward_normalized': 'Bình Sa'}
# Actual   : {'province': '', 'district': 'Thăng Bình', 'ward': '', 'province_normalized': '', 'district_normalized': 'Thăng Bình', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.008601s
# ------------------------------
# Case #342 ---
# Input    : 'XãGia Vượng, Gia Viễn, '
# Expected : {'district': 'Gia Viễn', 'ward': 'Gia Vượng', 'province': '', 'province_normalized': '', 'district_normalized': 'Gia Viễn', 'ward_normalized': 'Gia Vượng'}
# Actual   : {'province': '', 'district': 'Gia Viễn', 'ward': '', 'province_normalized': '', 'district_normalized': 'Gia Viễn', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.007985s
# ------------------------------
# Case #344 ---
# Input    : 'Thị trấnSông Đốc, , TnhCà Mau'
# Expected : {'district': '', 'ward': 'Sông Đốc', 'province': 'Cà Mau', 'province_normalized': 'Cà Mau', 'district_normalized': '', 'ward_normalized': 'Sông Đốc'}
# Actual   : {'province': 'Cà Mau', 'district': '', 'ward': '', 'province_normalized': 'Cà Mau', 'district_normalized': '', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.008665s
# ------------------------------
# Case #349 ---
# Input    : 'F.Dịch Vọng  C/Giấy Thành phốHàNội'
# Expected : {'district': 'Cầu Giấy', 'ward': 'Dịch Vọng', 'province': 'Hà Nội', 'province_normalized': 'Hà Nội', 'district_normalized': 'Cầu Giấy', 'ward_normalized': 'Dịch Vọng'}
# Actual   : {'province': 'Hà Nội', 'district': '', 'ward': 'Dịch Vọng', 'province_normalized': 'Hà Nội', 'district_normalized': '', 'ward_normalized': 'Dịch Vọng'}
# Correct  : 2/3
# Time     : 0.010601s
# ------------------------------
# Case #351 ---
# Input    : ' Ea Huar,HuyệnBuôn Đôn,'
# Expected : {'district': 'Buôn Đôn', 'ward': 'Ea Huar', 'province': '', 'province_normalized': '', 'district_normalized': 'Buôn Đôn', 'ward_normalized': 'Ea Huar'}
# Actual   : {'province': '', 'district': 'Buôn Đôn', 'ward': '', 'province_normalized': '', 'district_normalized': 'Buôn Đôn', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.006517s
# ------------------------------
# Case #353 ---
# Input    : 'X Tân Thanh Huyện Lang Giang '
# Expected : {'district': 'Lạng Giang', 'ward': 'Tân Thanh', 'province': '', 'province_normalized': '', 'district_normalized': 'Lạng Giang', 'ward_normalized': 'Tân Thanh'}
# Actual   : {'province': 'An Giang', 'district': '', 'ward': 'Tân Thạnh', 'province_normalized': 'An Giang', 'district_normalized': '', 'ward_normalized': 'Tân Thạnh'}
# Correct  : 0/3
# Time     : 0.005269s
# ------------------------------
# Case #354 ---
# Input    : 'X. Sơn Hv HSơn Hoa Tỉnh Phú Yên'
# Expected : {'district': 'Sơn Hòa', 'ward': 'Sơn Hội', 'province': 'Phú Yên', 'province_normalized': 'Phú Yên', 'district_normalized': 'Sơn Hòa', 'ward_normalized': 'Sơn Hội'}
# Actual   : {'province': 'Phú Yên', 'district': '', 'ward': 'Sơn Hà', 'province_normalized': 'Phú Yên', 'district_normalized': '', 'ward_normalized': 'Sơn Hà'}
# Correct  : 1/3
# Time     : 0.008429s
# ------------------------------
# Case #356 ---
# Input    : 'Công Hòa H.Kim Thành '
# Expected : {'district': 'Kim Thành', 'ward': 'Cộng Hòa', 'province': '', 'province_normalized': '', 'district_normalized': 'Kim Thành', 'ward_normalized': 'cộng hòa'}
# Actual   : {'province': '', 'district': 'Kim Thành', 'ward': '', 'province_normalized': '', 'district_normalized': 'Kim Thành', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.009465s
# ------------------------------
# Case #360 ---
# Input    : '  Quỳ Châu T.NSghệ An'
# Expected : {'district': 'Quỳ Châu', 'ward': '', 'province': 'Nghệ An', 'province_normalized': 'Nghệ An', 'district_normalized': 'Quỳ Châu', 'ward_normalized': ''}
# Actual   : {'province': 'Nghệ An', 'district': '', 'ward': '', 'province_normalized': 'Nghệ An', 'district_normalized': '', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.007395s
# ------------------------------
# Case #369 ---
# Input    : 'X.Cẩm Hoàng,,T. Hải Dươnwg'
# Expected : {'district': '', 'ward': 'Cẩm Hoàng', 'province': 'Hải Dương', 'province_normalized': 'Hải Dương', 'district_normalized': '', 'ward_normalized': 'Cẩm Hoàng'}
# Actual   : {'province': 'Hải Dương', 'district': '', 'ward': 'Cẩm Giang', 'province_normalized': 'Hải Dương', 'district_normalized': '', 'ward_normalized': 'Cẩm Giang'}
# Correct  : 2/3
# Time     : 0.003815s
# ------------------------------
# Case #370 ---
# Input    : 'X. Cat Chánh,HuyệnPhù Cát,'
# Expected : {'district': 'Phù Cát', 'ward': 'Cát Chánh', 'province': '', 'province_normalized': '', 'district_normalized': 'Phù Cát', 'ward_normalized': 'Cát Chánh'}
# Actual   : {'province': '', 'district': 'Phù Cát', 'ward': '', 'province_normalized': '', 'district_normalized': 'Phù Cát', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.011432s
# ------------------------------
# Case #371 ---
# Input    : ' Ea Kmút,hyệnea Kar,Tỉnwh Đắk Lắk'
# Expected : {'district': 'Ea Kar', 'ward': 'Ea Kmút', 'province': 'Đắk Lắk', 'province_normalized': 'Đắk Lắk', 'district_normalized': 'Ea Kar', 'ward_normalized': 'Ea Kmút'}
# Actual   : {'province': 'Đắk Lắk', 'district': '', 'ward': 'Ea Kmút', 'province_normalized': 'Đắk Lắk', 'district_normalized': '', 'ward_normalized': 'Ea Kmút'}
# Correct  : 2/3
# Time     : 0.010780s
# ------------------------------
# Case #374 ---
# Input    : 'Xã C.hâu Minh, HHiệp Ha, TBắc Giang'
# Expected : {'district': 'Hiệp Hòa', 'ward': 'Châu Minh', 'province': 'Bắc Giang', 'province_normalized': 'Bắc Giang', 'district_normalized': 'Hiệp Hòa', 'ward_normalized': 'Châu Minh'}
# Actual   : {'province': 'Bắc Giang', 'district': '', 'ward': 'Châu Minh', 'province_normalized': 'Bắc Giang', 'district_normalized': '', 'ward_normalized': 'Châu Minh'}
# Correct  : 2/3
# Time     : 0.010148s
# ------------------------------
# Case #376 ---
# Input    : 'Diên Thạnh,,T Khabnh Hòa'
# Expected : {'district': '', 'ward': 'Diên Thạnh', 'province': 'Khánh Hòa', 'province_normalized': 'Khánh Hòa', 'district_normalized': '', 'ward_normalized': 'Diên Thạnh'}
# Actual   : {'province': 'Khánh Hòa', 'district': 'Diên Khánh', 'ward': '', 'province_normalized': 'Khánh Hòa', 'district_normalized': 'Diên Khánh', 'ward_normalized': ''}
# Correct  : 1/3
# Time     : 0.001162s
# ------------------------------
# Case #378 ---
# Input    : 'X.Đức Sơn Anh Sơn '
# Expected : {'district': 'Anh Sơn', 'ward': 'Đức Sơn', 'province': '', 'province_normalized': '', 'district_normalized': 'Anh Sơn', 'ward_normalized': 'Đức Sơn'}
# Actual   : {'province': '', 'district': 'Anh Sơn', 'ward': '', 'province_normalized': '', 'district_normalized': 'Anh Sơn', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.006891s
# ------------------------------
# Case #384 ---
# Input    : 'X Song Lộc H.Châu Thành '
# Expected : {'district': 'Châu Thành', 'ward': 'Song Lộc', 'province': '', 'province_normalized': '', 'district_normalized': 'Châu Thành', 'ward_normalized': 'Song Lộc'}
# Actual   : {'province': '', 'district': 'Châu Thành', 'ward': '', 'province_normalized': '', 'district_normalized': 'Châu Thành', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.009766s
# ------------------------------
# Case #386 ---
# Input    : 'X. Bản Nguyen,HuyệnLâm Thao,'
# Expected : {'district': 'Lâm Thao', 'ward': 'Bản Nguyên', 'province': '', 'province_normalized': '', 'district_normalized': 'Lâm Thao', 'ward_normalized': 'Bản Nguyên'}
# Actual   : {'province': '', 'district': 'Lâm Thao', 'ward': '', 'province_normalized': '', 'district_normalized': 'Lâm Thao', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.010246s
# ------------------------------
# Case #394 ---
# Input    : ' Quận 1 T.P H.C.Minh'
# Expected : {'district': '1', 'ward': '', 'province': 'Hồ Chí Minh', 'province_normalized': 'Hồ Chí Minh', 'district_normalized': '1', 'ward_normalized': ''}
# Actual   : {'province': '', 'district': 'U Minh', 'ward': '', 'province_normalized': '', 'district_normalized': 'U Minh', 'ward_normalized': ''}
# Correct  : 1/3
# Time     : 0.007687s
# ------------------------------
# Case #400 ---
# Input    : 'oã Bnh Ngọc,T.Phố Tuy Hoà,Tỉnhphú Yên'
# Expected : {'district': 'Tuy Hoà', 'ward': 'Bình Ngọc', 'province': 'Phú Yên', 'province_normalized': 'Phú Yên', 'district_normalized': 'Tuy Hoà', 'ward_normalized': 'Bình Ngọc'}
# Actual   : {'province': 'Phú Yên', 'district': '', 'ward': 'Bình Ngọc', 'province_normalized': 'Phú Yên', 'district_normalized': '', 'ward_normalized': 'Bình Ngọc'}
# Correct  : 2/3
# Time     : 0.006299s
# ------------------------------
# Case #401 ---
# Input    : ' Chương Dương, HuyệnĐôngHưng, '
# Expected : {'district': 'Đông Hưng', 'ward': 'Chương Dương', 'province': '', 'province_normalized': '', 'district_normalized': 'Đông Hưng', 'ward_normalized': 'Chương Dương'}
# Actual   : {'province': '', 'district': 'Tương Dương', 'ward': '', 'province_normalized': '', 'district_normalized': 'Tương Dương', 'ward_normalized': ''}
# Correct  : 1/3
# Time     : 0.018176s
# ------------------------------
# Case #403 ---
# Input    : ' T.P Phan Rang-Tháp lhàm  Ninh Thuận'
# Expected : {'district': 'Phan Rang-Tháp Chàm', 'ward': '', 'province': 'Ninh Thuận', 'province_normalized': 'Ninh Thuận', 'district_normalized': 'Phan Rang-Tháp Chàm', 'ward_normalized': ''}
# Actual   : {'province': 'Ninh Thuận', 'district': '', 'ward': '', 'province_normalized': 'Ninh Thuận', 'district_normalized': '', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.008343s
# ------------------------------
# Case #409 ---
# Input    : ' Đức Lĩnh,Vũ Quang,'
# Expected : {'district': 'Vũ Quang', 'ward': 'Đức Lĩnh', 'province': '', 'province_normalized': '', 'district_normalized': 'Vũ Quang', 'ward_normalized': 'Đức Lĩnh'}
# Actual   : {'province': '', 'district': 'Đức Linh', 'ward': '', 'province_normalized': '', 'district_normalized': 'Đức Linh', 'ward_normalized': ''}
# Correct  : 1/3
# Time     : 0.022172s
# ------------------------------
# Case #410 ---
# Input    : 'XQuỳnh Hôi, Quỳnh Phụ, Thái Bình'
# Expected : {'district': 'Quỳnh Phụ', 'ward': 'Quỳnh Hội', 'province': 'Thái Bình', 'province_normalized': 'Thái Bình', 'district_normalized': 'Quỳnh Phụ', 'ward_normalized': 'Quỳnh Hội'}
# Actual   : {'province': 'Thái Bình', 'district': 'Quỳnh Phụ', 'ward': '', 'province_normalized': 'Thái Bình', 'district_normalized': 'Quỳnh Phụ', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.001060s
# ------------------------------
# Case #411 ---
# Input    : ' Yn phú, HBắc Mê, TỉnhV Hà giang'
# Expected : {'district': 'Bắc Mê', 'ward': 'Yên Phú', 'province': 'Hà Giang', 'province_normalized': 'Hà Giang', 'district_normalized': 'Bắc Mê', 'ward_normalized': 'Yên Phú'}
# Actual   : {'province': 'Hà Giang', 'district': 'Bắc Mê', 'ward': '', 'province_normalized': 'Hà Giang', 'district_normalized': 'Bắc Mê', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.001055s
# ------------------------------
# Case #412 ---
# Input    : 'Xuân Tân t.P Long Khánh '
# Expected : {'district': 'Long Khánh', 'ward': 'Xuân Tân', 'province': '', 'province_normalized': '', 'district_normalized': 'Long Khánh', 'ward_normalized': 'Xuân Tân'}
# Actual   : {'province': '', 'district': 'Long Khánh', 'ward': '', 'province_normalized': '', 'district_normalized': 'Long Khánh', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.011507s
# ------------------------------
# Case #417 ---
# Input    : 'Phú Đô HuyệnPhú Lươnz '
# Expected : {'district': 'Phú Lương', 'ward': 'Phú Đô', 'province': '', 'province_normalized': '', 'district_normalized': 'Phú Lương', 'ward_normalized': 'Phú Đô'}
# Actual   : {'province': '', 'district': 'Phú Lương', 'ward': '', 'province_normalized': '', 'district_normalized': 'Phú Lương', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.009178s
# ------------------------------
# Case #421 ---
# Input    : 'TTr.Quỳnh Côi,HQuỳnh Phụ,TThai Bình'
# Expected : {'district': 'Quỳnh Phụ', 'ward': 'Quỳnh Côi', 'province': 'Thái Bình', 'province_normalized': 'Thái Bình', 'district_normalized': 'Quỳnh Phụ', 'ward_normalized': 'Quỳnh Côi'}
# Actual   : {'province': 'Thái Bình', 'district': '', 'ward': 'Quỳnh Côi', 'province_normalized': 'Thái Bình', 'district_normalized': '', 'ward_normalized': 'Quỳnh Côi'}
# Correct  : 2/3
# Time     : 0.007997s
# ------------------------------
# Case #422 ---
# Input    : ', Nam Đông,T. T.T.H'
# Expected : {'district': 'Nam Đông', 'ward': '', 'province': 'Thừa Thiên Huế', 'province_normalized': 'Thừa Thiên Huế', 'district_normalized': 'Nam Đông', 'ward_normalized': ''}
# Actual   : {'province': '', 'district': 'Nam Đông', 'ward': '', 'province_normalized': '', 'district_normalized': 'Nam Đông', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.020780s
# ------------------------------
# Case #424 ---
# Input    : 'TTĐức An Huyện Đắk SongTỉnhĐắk Nông'
# Expected : {'district': 'Đắk Song', 'ward': 'Đức An', 'province': 'Đắk Nông', 'province_normalized': 'Đắk Nông', 'district_normalized': 'Đắk Song', 'ward_normalized': 'Đức An'}
# Actual   : {'province': '', 'district': '', 'ward': '', 'province_normalized': '', 'district_normalized': '', 'ward_normalized': ''}
# Correct  : 0/3
# Time     : 0.042499s
# ------------------------------
# Case #426 ---
# Input    : 'X Đoàn đào,4 Phù Cừ,T.Hưng Yên'
# Expected : {'district': 'Phù Cừ', 'ward': 'Đoàn Đào', 'province': 'Hưng Yên', 'province_normalized': 'Hưng Yên', 'district_normalized': 'Phù Cừ', 'ward_normalized': 'Đoàn Đào'}
# Actual   : {'province': 'Hưng Yên', 'district': 'Phù Cừ', 'ward': '', 'province_normalized': 'Hưng Yên', 'district_normalized': 'Phù Cừ', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.001334s
# ------------------------------
# Case #428 ---
# Input    : ',H.Hoài ân,TBình Dịnh'
# Expected : {'district': 'Hoài Ân', 'ward': '', 'province': 'Bình Định', 'province_normalized': 'Bình Định', 'district_normalized': 'Hoài Ân', 'ward_normalized': ''}
# Actual   : {'province': 'Bình Định', 'district': '', 'ward': '', 'province_normalized': 'Bình Định', 'district_normalized': '', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.004267s
# ------------------------------
# Case #441 ---
# Input    : 'P Thủy Châu,T.X. hươngThủy,Thừa.t.Huế'
# Expected : {'district': 'Hương Thủy', 'ward': 'Thủy Châu', 'province': 'Thừa Thiên Huế', 'province_normalized': 'Thừa Thiên Huế', 'district_normalized': 'Hương Thủy', 'ward_normalized': 'Thủy Châu'}
# Actual   : {'province': '', 'district': 'Huế', 'ward': '', 'province_normalized': '', 'district_normalized': 'Huế', 'ward_normalized': ''}
# Correct  : 0/3
# Time     : 0.017124s
# ------------------------------
# Case #442 ---
# Input    : 'Thi trấ Ea. Knốp,H. Ea Kar,'
# Expected : {'district': 'Ea Kar', 'ward': 'Ea Knốp', 'province': '', 'province_normalized': '', 'district_normalized': 'Ea Kar', 'ward_normalized': 'Ea Knốp'}
# Actual   : {'province': '', 'district': 'Ea Kar', 'ward': '', 'province_normalized': '', 'district_normalized': 'Ea Kar', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.010334s
# ------------------------------
# Case #447 ---
# Input    : 'F Tân bình  dĩ An '
# Expected : {'district': 'Dĩ An', 'ward': 'Tân Bình', 'province': '', 'province_normalized': '', 'district_normalized': 'Dĩ An', 'ward_normalized': 'Tân Bình'}
# Actual   : {'province': '', 'district': 'Dĩ An', 'ward': '', 'province_normalized': '', 'district_normalized': 'Dĩ An', 'ward_normalized': ''}
# Correct  : 2/3
# Time     : 0.008899s
# ------------------------------
# Summary
# TEAM_NAME = 'HK251'
# EXCEL_FILE = 'HK251.xlsx'
#    correct  total  score / 10  max_time_sec  avg_time_sec
# 0     1194   1350        8.84        0.2741        0.0042
